# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Karnataka

# %%
acc_with_issues = pd.read_excel('ATC_MTD Dashboard_till Oct01-Oct29.xlsx',sheet_name=1)
acc_with_issues
# Out:
#     Normalized Account Number  Account Number  \
# 0                  1210749222      1210749222
# 1                  1867207000      1867207000
# 2                  1881365201      1881365201
# 3                  2151207000      2151207000
# 4                  2174996000      2174996000
# ..                        ...             ...
# 526              813001110327    813001110327
# 527              813001110378    813001110378
# 528              813001110468    813001110468
# 529              416001110318  4160 0111 0318
# 530              911001060286  9110 0106 0286
#
#                       Provider Alias Monitoring Status  \
# 0    BangaloreElectricitySupplyCoIND          INACTIVE
# 1    BangaloreElectricitySupplyCoIND          INACTIVE
# 2    BangaloreElectricitySupplyCoIND          INACTIVE
# 3    BangaloreElectricitySupplyCoIND          INACTIVE
# 4    BangaloreElectricitySupplyCoIND          INACTIVE
# ..                               ...               ...
# 526                        TPWODLIND          INACTIVE
# 527                        TPWODLIND          INACTIVE
# 528                        TPWODLIND          INACTIVE
# 529                         WESCOIND          INACTIVE
# 530                         WESCOIND          INACTIVE
#
#                                        Detailed Status  Site Code      CNBD 2  \
# 0    Since the invoice is not posted for more than ...     588720  9794689077
# 1    Since the invoice is not posted for more than ...     551605  1867207000
# 2    Since the invoice is not posted for more than ...     585096  1341011564
# 3    Since the invoice is not posted for more than ...     551054  2151207000
# 4    Since the invoice is not posted for more than ...     550465  2174996000
# ..                                                 ...        ...         ...
# 526  Since the invoice is not posted for more than ...     568983         NaN
# 527  Since the invoice is not posted for more than ...     453636         NaN
# 528  Since the invoice is not posted for more than ...     571767         NaN
# 529  Since the invoice is not posted for more than ...     508434         NaN
# 530  Since the invoice is not posted for more than ...     454203         NaN
#
#     CircleName
# 0    Karnataka
# 1    Karnataka
# 2    Karnataka
# 3    Karnataka
# 4    Karnataka
# ..         ...
# 526     Orissa
# 527     Orissa
# 528     Orissa
# 529     Orissa
# 530     Orissa
#
# [531 rows x 8 columns]

# %%
acc_with_issue_final = acc_with_issues[(acc_with_issues.CircleName == "Karnataka")]
acc_with_issue_final
# Out:
#     Normalized Account Number Account Number                   Provider Alias  \
# 0                  1210749222     1210749222  BangaloreElectricitySupplyCoIND
# 1                  1867207000     1867207000  BangaloreElectricitySupplyCoIND
# 2                  1881365201     1881365201  BangaloreElectricitySupplyCoIND
# 3                  2151207000     2151207000  BangaloreElectricitySupplyCoIND
# 4                  2174996000     2174996000  BangaloreElectricitySupplyCoIND
# ..                        ...            ...                              ...
# 174                7015773000     7015773000      HubliElectricitySupplyCoIND
# 175                7152362059     7152362059      HubliElectricitySupplyCoIND
# 176                9564001839     9564001839      HubliElectricitySupplyCoIND
# 177                9687489559     9687489559      HubliElectricitySupplyCoIND
# 178                9753204164     9753204164      HubliElectricitySupplyCoIND
#
#     Monitoring Status                                    Detailed Status  \
# 0            INACTIVE  Since the invoice is not posted for more than ...
# 1            INACTIVE  Since the invoice is not posted for more than ...
# 2            INACTIVE  Since the invoice is not posted for more than ...
# 3            INACTIVE  Since the invoice is not posted for more than ...
# 4            INACTIVE  Since the invoice is not posted for more than ...
# ..                ...                                                ...
# 174         AGED_BILL        'No New Bill posted in website after 45days
# 175          INACTIVE  Since the invoice is not posted for more than ...
# 176          INACTIVE  Since the invoice is not posted for more than ...
# 177          INACTIVE  Since the invoice is not posted for more than ...
# 178         AGED_BILL        'No New Bill posted in website after 45days
#
#      Site Code      CNBD 2 CircleName
# 0       588720  9794689077  Karnataka
# 1       551605  1867207000  Karnataka
# 2       585096  1341011564  Karnataka
# 3       551054  2151207000  Karnataka
# 4       550465  2174996000  Karnataka
# ..         ...         ...        ...
# 174     571904     119561C  Karnataka
# 175     584542      BT5483  Karnataka
# 176     583727  TEMP1.2249  Karnataka
# 177     527239  4761809365  Karnataka
# 178     588168      T12130  Karnataka
#
# [134 rows x 8 columns]

# %%
del_fail = pd.read_excel('ATC_MTD Dashboard_till Oct01-Oct29.xlsx',sheet_name=3)
del_fail
# Out:
#             Date                       StatementId  AccountNumber  \
# 0     01.10.2021  1ec21e2e51e3d3b29e9f0e0f977cb1e5    60005671684
# 1     01.10.2021  1ec21e36493ed6f19e9f0e0f977cb1e5    60002942351
# 2     04.10.2021  1ec22c05e889dfb291fa0e3afc394ba3     B612247431
# 3     04.10.2021  1ec22c0687fbddba91fa0e3afc394ba3     B526248876
# 4     04.10.2021  1ec22ce0e5c7d3f5989c0edcfb1d6363     B725319852
# ...          ...                               ...            ...
# 3398  29.10.2021  1ec3825fe65ed9d197a20e15626d9e8f     5172016695
# 3399  29.10.2021  1ec382a56b5fd5bb87d10edda61bcaa7    N3688011387
# 3400  29.10.2021  1ec382e3e91ddb31807d0e0b6aa255cd    72380057280
# 3401  29.10.2021  1ec383996413d5f4be890e15626d9e8f  323-289-003*5
# 3402  29.10.2021  1ec383f6a311d823be890e15626d9e8f  799-437-063*2
#
#                                      ProviderAlias         Circle  SiteCode  \
# 0                            GoaElectricityDeptIND    Maharashtra    461363
# 1                            GoaElectricityDeptIND    Maharashtra    567022
# 2              GulbargaElectricitySupplyCompanyIND      Karnataka    580799
# 3              GulbargaElectricitySupplyCompanyIND      Karnataka    524030
# 4              GulbargaElectricitySupplyCompanyIND      Karnataka    500218
# ...                                            ...            ...       ...
# 3398                  TamilNaduElectricityBoardIND      TamilNadu    590567
# 3399            MPPaschimKshetraVidyutVitaranCoIND  MadhyaPradesh    558127
# 3400                  TamilNaduElectricityBoardIND      TamilNadu    587295
# 3401  TheBrihanmumbaiElectricSupplyAndTransportIND         Mumbai    592227
# 3402  TheBrihanmumbaiElectricSupplyAndTransportIND         Mumbai    567608
#
#      Statementdate            DeliveryResult  ResponseCode  \
# 0       2021-10-01   NOT_WANTED_API_REJECTED           400
# 1       2021-10-01  NOT_WANTED_API_DUPLICATE           409
# 2       2021-10-01   NOT_WANTED_API_REJECTED           400
# 3       2021-10-01   NOT_WANTED_API_REJECTED           400
# 4       2021-10-03   NOT_WANTED_API_REJECTED           400
# ...            ...                       ...           ...
# 3398    2021-10-28   NOT_WANTED_API_REJECTED           400
# 3399    2021-10-28   NOT_WANTED_API_REJECTED           400
# 3400    2021-10-28   NOT_WANTED_API_REJECTED           400
# 3401    2021-10-28   NOT_WANTED_API_REJECTED           400
# 3402    2021-10-28   NOT_WANTED_API_REJECTED           400
#
#                                            ResponseBody
# 0     {"message":"No EB Master found for SiteId/Cons...
# 1     {"message":"EB Feed details already exists - S...
# 2     {"message":"No EB Master found for SiteId/Cons...
# 3     {"message":"No EB Master found for SiteId/Cons...
# 4     {"message":"No EB Master found for SiteId/Cons...
# ...                                                 ...
# 3398  {"message":"No EB Master found for SiteId/Cons...
# 3399  {"message":"No EB Master found for SiteId/Cons...
# 3400       {"message":"No EB Master defined for SiteId"
# 3401  {"message":"No EB Master found for SiteId/Cons...
# 3402  {"message":"No EB Master found for SiteId/Cons...
#
# [3403 rows x 10 columns]

# %%
del_fail_final = del_fail[(del_fail.Circle == "Karnataka")]
del_fail_final
# Out:
#             Date                       StatementId AccountNumber  \
# 2     04.10.2021  1ec22c05e889dfb291fa0e3afc394ba3    B612247431
# 3     04.10.2021  1ec22c0687fbddba91fa0e3afc394ba3    B526248876
# 4     04.10.2021  1ec22ce0e5c7d3f5989c0edcfb1d6363    B725319852
# 13    04.10.2021  1ec2302c3f4cddf384100e1b02cd6113       1838137
# 167   05.10.2021  1ec250769a73dfc1b0380e705fe33a37       4164048
# 168   05.10.2021  1ec2507832b8d9f3b0380e705fe33a37       4411248
# 169   05.10.2021  1ec25079eb82d641b0380e705fe33a37       4290597
# 170   05.10.2021  1ec2508d6894d933b0380e705fe33a37       4819914
# 171   05.10.2021  1ec2508ecfded1beb0380e705fe33a37       4845657
# 286   06.10.2021  1ec259251788daedbdad0ea9967be5d7    3896822222
# 301   06.10.2021  1ec2599cc987d49ebdad0ea9967be5d7    3340755555
# 382   06.10.2021  1ec2607ccf77da66b1240e85c2d2de21       3642419
# 576   06.10.2021  1ec22d423062d90d925b0e3831c81f97    4869031000
# 577   06.10.2021  1ec24fb59cb9dc3fa5bc0e705fe33a37    2305871000
# 578   06.10.2021  1ec24fb5ae06d832a5bc0e705fe33a37    5716871000
# 579   06.10.2021  1ec24fb5be88d8f5a5bc0e705fe33a37    9695871000
# 580   06.10.2021  1ec24fb5cf3ddf08a5bc0e705fe33a37    2971603000
# 581   06.10.2021  1ec24fb5e868dc96a5bc0e705fe33a37    1144872000
# 582   06.10.2021  1ec24fb5f83fdff9a5bc0e705fe33a37    4671532000
# 583   06.10.2021  1ec24fb60851dbdca5bc0e705fe33a37    3542883000
# 584   06.10.2021  1ec24fb61861d0afa5bc0e705fe33a37    9765132000
# 585   06.10.2021  1ec24fb628afde22a5bc0e705fe33a37    6687772000
# 586   06.10.2021  1ec24fb638e8db05a5bc0e705fe33a37     657379416
# 587   06.10.2021  1ec24fb64a83d903a5bc0e705fe33a37    2635832000
# 588   06.10.2021  1ec24fb65a9cda16a5bc0e705fe33a37     421108261
# 589   06.10.2021  1ec24fb66b7bd739a5bc0e705fe33a37    1305871000
# 590   06.10.2021  1ec24fb67ba0dc9ca5bc0e705fe33a37     610644444
# 591   06.10.2021  1ec24fb68c73d66fa5bc0e705fe33a37    1658193000
# 592   06.10.2021  1ec24fb69d21d752a5bc0e705fe33a37    2616920867
# 593   06.10.2021  1ec250a53969d2749c8b0eeeb76e7983    4946032000
# 594   06.10.2021  1ec250a547a8d9769c8b0eeeb76e7983    7971391000
# 595   06.10.2021  1ec2517f4aa9dbe2a80a0e7cbc6cb6a5    6244522222
# 596   06.10.2021  1ec2517f88a9d57aa80a0e7cbc6cb6a5    3693411111
# 597   06.10.2021  1ec2517fb4ffd6c0a80a0e7cbc6cb6a5    2367944444
# 598   06.10.2021  1ec2517fffc8dfbaa80a0e7cbc6cb6a5     493411111
# 599   06.10.2021  1ec25180a47cd060a80a0e7cbc6cb6a5    8944014444
# 600   06.10.2021  1ec25180fd20debca80a0e7cbc6cb6a5    9327514000
# 601   06.10.2021  1ec251810bdcdddea80a0e7cbc6cb6a5    8511011111
# 602   06.10.2021  1ec2518137fdd4c4a80a0e7cbc6cb6a5    8959806803
# 603   06.10.2021  1ec251816431d32aa80a0e7cbc6cb6a5    4051824000
# 604   06.10.2021  1ec25d7b8c30de73960b0eeeb76e7983    1292168000
# 660   07.10.2021  1ec267f0b732d47a94610eeeb76e7983    2814268118
# 688   07.10.2021  1ec26a80dd27d49289190eece2fa5bfb    5949681000
# 745   07.10.2021  1ec26c2da6e5df53b3f80e2f16d0a88b    5987266390
# 761   07.10.2021  1ec26cd5568bd7ff87150e2f16d0a88b    6567839340
# 915   07.10.2021  1ec26cd48dc4d94bb3f80e2f16d0a88b    5873220000
# 1033  08.10.2021  1ec278ebf96ed88f8f3e0e62b4a9a05b       4332129
# 1096  08.10.2021  1ec27a130a6fda518ba70e6276e7ddf1    7853383000
# 1252  11.10.2021  1ec28145494fdd73bd7e0eece2fa5bfb    6195422000
# 1296  11.10.2021  1ec2842a988cdcf0a9160eece2fa5bfb    9015186308
# 1298  11.10.2021  1ec28467ceb9db45a9a10e40024f9825    3890056000
# 2171  13.10.2021  1ec2b14fbaf9d10e9b1b0efde6fe87a5    5193667582
# 2270  13.10.2021  1ec2b6015edbdfd79d5f0e96ae896db5       2145635
# 2330  13.10.2021  1ec2b8452a62d43d85340ea06d1a8b41    4353527000
# 2484  14.10.2021  1ec2c4f0a065dc1a8d260e7cbc6cb6a5       4031267
# 3392  29.10.2021  1ec37cd5ed60d45f817e0e5cbcca8d47       3027730
#
#                                ProviderAlias     Circle  SiteCode  \
# 2        GulbargaElectricitySupplyCompanyIND  Karnataka    580799
# 3        GulbargaElectricitySupplyCompanyIND  Karnataka    524030
# 4        GulbargaElectricitySupplyCompanyIND  Karnataka    500218
# 13               HubliElectricitySupplyCoIND  Karnataka    550717
# 167              HubliElectricitySupplyCoIND  Karnataka    574825
# 168              HubliElectricitySupplyCoIND  Karnataka    580796
# 169              HubliElectricitySupplyCoIND  Karnataka    580809
# 170              HubliElectricitySupplyCoIND  Karnataka    584586
# 171              HubliElectricitySupplyCoIND  Karnataka    585780
# 286      GulbargaElectricitySupplyCompanyIND  Karnataka    552439
# 301      GulbargaElectricitySupplyCompanyIND  Karnataka    571257
# 382              HubliElectricitySupplyCoIND  Karnataka    549909
# 576              HubliElectricitySupplyCoIND  Karnataka    552458
# 577      GulbargaElectricitySupplyCompanyIND  Karnataka    550014
# 578      GulbargaElectricitySupplyCompanyIND  Karnataka    549983
# 579      GulbargaElectricitySupplyCompanyIND  Karnataka    500708
# 580      GulbargaElectricitySupplyCompanyIND  Karnataka    500695
# 581      GulbargaElectricitySupplyCompanyIND  Karnataka    500745
# 582      GulbargaElectricitySupplyCompanyIND  Karnataka    549643
# 583      GulbargaElectricitySupplyCompanyIND  Karnataka    550214
# 584      GulbargaElectricitySupplyCompanyIND  Karnataka    551071
# 585      GulbargaElectricitySupplyCompanyIND  Karnataka    573023
# 586      GulbargaElectricitySupplyCompanyIND  Karnataka    574824
# 587      GulbargaElectricitySupplyCompanyIND  Karnataka    551078
# 588      GulbargaElectricitySupplyCompanyIND  Karnataka    580995
# 589      GulbargaElectricitySupplyCompanyIND  Karnataka    550013
# 590      GulbargaElectricitySupplyCompanyIND  Karnataka    551843
# 591      GulbargaElectricitySupplyCompanyIND  Karnataka    551928
# 592      GulbargaElectricitySupplyCompanyIND  Karnataka    575279
# 593          BangaloreElectricitySupplyCoIND  Karnataka    552403
# 594          BangaloreElectricitySupplyCoIND  Karnataka    552171
# 595   ChamundeshwariElectricitySupplyCorpIND  Karnataka    550619
# 596   ChamundeshwariElectricitySupplyCorpIND  Karnataka    552472
# 597   ChamundeshwariElectricitySupplyCorpIND  Karnataka    551857
# 598   ChamundeshwariElectricitySupplyCorpIND  Karnataka    551263
# 599   ChamundeshwariElectricitySupplyCorpIND  Karnataka    550226
# 600   ChamundeshwariElectricitySupplyCorpIND  Karnataka    551812
# 601   ChamundeshwariElectricitySupplyCorpIND  Karnataka    550623
# 602   ChamundeshwariElectricitySupplyCorpIND  Karnataka    571783
# 603   ChamundeshwariElectricitySupplyCorpIND  Karnataka    550169
# 604          BangaloreElectricitySupplyCoIND  Karnataka    549454
# 660   ChamundeshwariElectricitySupplyCorpIND  Karnataka    551311
# 688              HubliElectricitySupplyCoIND  Karnataka    550320
# 745          BangaloreElectricitySupplyCoIND  Karnataka    585915
# 761          BangaloreElectricitySupplyCoIND  Karnataka    578078
# 915          BangaloreElectricitySupplyCoIND  Karnataka    552444
# 1033             HubliElectricitySupplyCoIND  Karnataka    580908
# 1096             HubliElectricitySupplyCoIND  Karnataka    500724
# 1252     GulbargaElectricitySupplyCompanyIND  Karnataka    549997
# 1296             HubliElectricitySupplyCoIND  Karnataka    571273
# 1298         BangaloreElectricitySupplyCoIND  Karnataka    549591
# 2171         BangaloreElectricitySupplyCoIND  Karnataka    526400
# 2270         BangaloreElectricitySupplyCoIND  Karnataka    552319
# 2330         BangaloreElectricitySupplyCoIND  Karnataka    550734
# 2484         BangaloreElectricitySupplyCoIND  Karnataka    525780
# 3392         BangaloreElectricitySupplyCoIND  Karnataka    552423
#
#      Statementdate            DeliveryResult  ResponseCode  \
# 2       2021-10-01   NOT_WANTED_API_REJECTED           400
# 3       2021-10-01   NOT_WANTED_API_REJECTED           400
# 4       2021-10-03   NOT_WANTED_API_REJECTED           400
# 13      2021-10-01   NOT_WANTED_API_REJECTED           400
# 167     2021-10-02   NOT_WANTED_API_REJECTED           400
# 168     2021-10-01   NOT_WANTED_API_REJECTED           400
# 169     2021-10-01   NOT_WANTED_API_REJECTED           400
# 170     2021-10-02   NOT_WANTED_API_REJECTED           400
# 171     2021-10-01   NOT_WANTED_API_REJECTED           400
# 286     2021-10-01   NOT_WANTED_API_REJECTED           400
# 301     2021-10-01   NOT_WANTED_API_REJECTED           400
# 382     2021-10-01   NOT_WANTED_API_REJECTED           400
# 576     2021-10-01   NOT_WANTED_API_REJECTED           400
# 577     2021-10-01  NOT_WANTED_API_DUPLICATE           409
# 578     2021-10-01  NOT_WANTED_API_DUPLICATE           409
# 579     2021-10-01  NOT_WANTED_API_DUPLICATE           409
# 580     2021-10-01  NOT_WANTED_API_DUPLICATE           409
# 581     2021-10-01  NOT_WANTED_API_DUPLICATE           409
# 582     2021-10-01  NOT_WANTED_API_DUPLICATE           409
# 583     2021-10-01  NOT_WANTED_API_DUPLICATE           409
# 584     2021-10-01  NOT_WANTED_API_DUPLICATE           409
# 585     2021-10-01  NOT_WANTED_API_DUPLICATE           409
# 586     2021-10-01  NOT_WANTED_API_DUPLICATE           409
# 587     2021-10-01  NOT_WANTED_API_DUPLICATE           409
# 588     2021-10-01  NOT_WANTED_API_DUPLICATE           409
# 589     2021-10-01  NOT_WANTED_API_DUPLICATE           409
# 590     2021-10-01  NOT_WANTED_API_DUPLICATE           409
# 591     2021-10-01  NOT_WANTED_API_DUPLICATE           409
# 592     2021-10-01  NOT_WANTED_API_DUPLICATE           409
# 593     2021-10-01  NOT_WANTED_API_DUPLICATE           409
# 594     2021-10-01  NOT_WANTED_API_DUPLICATE           409
# 595     2021-10-01  NOT_WANTED_API_DUPLICATE           409
# 596     2021-10-01  NOT_WANTED_API_DUPLICATE           409
# 597     2021-10-01  NOT_WANTED_API_DUPLICATE           409
# 598     2021-10-01  NOT_WANTED_API_DUPLICATE           409
# 599     2021-10-01  NOT_WANTED_API_DUPLICATE           409
# 600     2021-10-01  NOT_WANTED_API_DUPLICATE           409
# 601     2021-10-01  NOT_WANTED_API_DUPLICATE           409
# 602     2021-10-01  NOT_WANTED_API_DUPLICATE           409
# 603     2021-10-01  NOT_WANTED_API_DUPLICATE           409
# 604     2021-10-01  NOT_WANTED_API_DUPLICATE           409
# 660     2021-10-04   NOT_WANTED_API_REJECTED           400
# 688     2021-10-03   NOT_WANTED_API_REJECTED           400
# 745     2021-10-03   NOT_WANTED_API_REJECTED           400
# 761     2021-10-02   NOT_WANTED_API_REJECTED           400
# 915     2021-10-03   NOT_WANTED_API_REJECTED           500
# 1033    2021-10-04   NOT_WANTED_API_REJECTED           400
# 1096    2021-10-01   NOT_WANTED_API_REJECTED           400
# 1252    2021-10-04   NOT_WANTED_API_REJECTED           400
# 1296    2021-10-02   NOT_WANTED_API_REJECTED           400
# 1298    2021-10-01   NOT_WANTED_API_REJECTED           502
# 2171    2021-10-11   NOT_WANTED_API_REJECTED           400
# 2270    2021-10-11   NOT_WANTED_API_REJECTED           400
# 2330    2021-10-06   NOT_WANTED_API_REJECTED           400
# 2484    2021-10-12   NOT_WANTED_API_REJECTED           400
# 3392    2021-10-04  NOT_WANTED_API_DUPLICATE           409
#
#                                            ResponseBody
# 2     {"message":"No EB Master found for SiteId/Cons...
# 3     {"message":"No EB Master found for SiteId/Cons...
# 4     {"message":"No EB Master found for SiteId/Cons...
# 13    {"message":"No EB Master found for SiteId/Cons...
# 167   {"message":"No EB Master found for SiteId/Cons...
# 168   {"message":"No EB Master found for SiteId/Cons...
# 169   {"message":"No EB Master found for SiteId/Cons...
# 170   {"message":"No EB Master found for SiteId/Cons...
# 171   {"message":"No EB Master found for SiteId/Cons...
# 286   {"message":"No EB Master found for SiteId/Cons...
# 301   {"message":"No EB Master found for SiteId/Cons...
# 382   {"message":"No EB Master found for SiteId/Cons...
# 576   {"message":"No EB Master found for SiteId/Cons...
# 577   {"message":"EB Feed details already exists - S...
# 578   {"message":"EB Feed details already exists - S...
# 579   {"message":"EB Feed details already exists - S...
# 580   {"message":"EB Feed details already exists - S...
# 581   {"message":"EB Feed details already exists - S...
# 582   {"message":"EB Feed details already exists - S...
# 583   {"message":"EB Feed details already exists - S...
# 584   {"message":"EB Feed details already exists - S...
# 585   {"message":"EB Feed details already exists - S...
# 586   {"message":"EB Feed details already exists - S...
# 587   {"message":"EB Feed details already exists - S...
# 588   {"message":"EB Feed details already exists - S...
# 589   {"message":"EB Feed details already exists - S...
# 590   {"message":"EB Feed details already exists - S...
# 591   {"message":"EB Feed details already exists - S...
# 592   {"message":"EB Feed details already exists - S...
# 593   {"message":"EB Feed details already exists - S...
# 594   {"message":"EB Feed details already exists - S...
# 595   {"message":"EB Feed details already exists - S...
# 596   {"message":"EB Feed details already exists - S...
# 597   {"message":"EB Feed details already exists - S...
# 598   {"message":"EB Feed details already exists - S...
# 599   {"message":"EB Feed details already exists - S...
# 600   {"message":"EB Feed details already exists - S...
# 601   {"message":"EB Feed details already exists - S...
# 602   {"message":"EB Feed details already exists - S...
# 603   {"message":"EB Feed details already exists - S...
# 604   {"message":"EB Feed details already exists - S...
# 660   {"message":"No EB Master found for SiteId/Cons...
# 688   {"message":"No EB Master found for SiteId/Cons...
# 745   {"message":"No EB Master found for SiteId/Cons...
# 761   {"message":"No EB Master found for SiteId/Cons...
# 915   {"message":"Validation failed for classes [com...
# 1033  {"message":"No EB Master found for SiteId/Cons...
# 1096  {"message":"No EB Master found for SiteId/Cons...
# 1252  {"message":"No EB Master found for SiteId/Cons...
# 1296  {"message":"No EB Master found for SiteId/Cons...
# 1298  <!DOCTYPE HTML PUBLIC "-//IETF//DTD HTML 2.0//...
# 2171  {"message":"No EB Master found for SiteId/Cons...
# 2270  {"message":"No EB Master found for SiteId/Cons...
# 2330  {"message":"No EB Master found for SiteId/Cons...
# 2484  {"message":"No EB Master found for SiteId/Cons...
# 3392  {"message":"EB Feed details already exists - S...

# %%
del_fail_final.shape
# Out:
# (56, 10)

# %%
def dfs_tabs(df_list, sheet_list, file_name):
    writer = pd.ExcelWriter(file_name,engine='xlsxwriter')   
    for dataframe, sheet in zip(df_list, sheet_list):
        dataframe.to_excel(writer, sheet_name=sheet, startrow=0 , startcol=0)   
    writer.save()


dfs = [acc_with_issue_final,del_fail_final]
sheets = ['Accounts with issues','Undelivered Accounts']    


dfs_tabs(dfs, sheets, 'Karnataka_Undelivered Accounts_Oct01-29.xlsx')

# %% [markdown]
# ### Andhra pradesh

# %%
acc_with_issue_AP = acc_with_issues[(acc_with_issues.CircleName == "AndhraPradesh")]
acc_with_issue_AP
# Out:
#     Normalized Account Number    Account Number Provider Alias  \
# 102          1111140000341976  1111140000341976      EPDCAPIND
# 103          1111280000212374  1111280000212374      EPDCAPIND
# 104          11139500C7009630  11139500C7009630      EPDCAPIND
# 105          1113950522000413  1113950522000413      EPDCAPIND
# 106          112101A100391959  112101A100391959      EPDCAPIND
# 107          1123121254352318  1123121254352318      EPDCAPIND
# 108          1123940000304102  1123940000304102      EPDCAPIND
# 109          1133442101005648  1133442101005648      EPDCAPIND
# 110          1165150126000826  1165150126000826      EPDCAPIND
# 111          1213280616000791  1213280616000791      EPDCAPIND
# 112          131101A100032180  131101A100032180      EPDCAPIND
# 113          131101A104064793  131101A104064793      EPDCAPIND
# 114          1433066201018037  1433066201018037      EPDCAPIND
# 115          1433066201018110  1433066201018110      EPDCAPIND
# 116          1451460204001810  1451460204001810      EPDCAPIND
# 117          1455440502018627  1455440502018627      EPDCAPIND
# 118          1511066103076535  1511066103076535      EPDCAPIND
# 119          1533581006018703  1533581006018703      EPDCAPIND
# 120          1552770404000346  1552770404000346      EPDCAPIND
#
#     Monitoring Status                                    Detailed Status  \
# 102          INACTIVE  Since the invoice is not posted for more than ...
# 103          INACTIVE  Since the invoice is not posted for more than ...
# 104     LOGIN_FAILURE  Not able to login in website since the credent...
# 105     LOGIN_FAILURE  Not able to login in website since the credent...
# 106          INACTIVE  Since the invoice is not posted for more than ...
# 107   ACCOUNT_MISSING  Account is missing in website so please check ...
# 108          INACTIVE  Since the invoice is not posted for more than ...
# 109         AGED_BILL        'No New Bill posted in website after 45days
# 110          INACTIVE  Since the invoice is not posted for more than ...
# 111  TEMPLATE_FAILURE       Work in progress for some errors in the bill
# 112          INACTIVE  Since the invoice is not posted for more than ...
# 113     LOGIN_FAILURE  Not able to login in website since the credent...
# 114   ACCOUNT_MISSING  Account is missing in website so please check ...
# 115   ACCOUNT_MISSING  Account is missing in website so please check ...
# 116         AGED_BILL        'No New Bill posted in website after 45days
# 117     LOGIN_FAILURE  Not able to login in website since the credent...
# 118          INACTIVE  Since the invoice is not posted for more than ...
# 119     LOGIN_FAILURE  Not able to login in website since the credent...
# 120          INACTIVE  Since the invoice is not posted for more than ...
#
#      Site Code              CNBD 2     CircleName
# 102     580772  ''1111140000341976  AndhraPradesh
# 103     563821  ''1111280000212374  AndhraPradesh
# 104     569034  ''11139500C7009630  AndhraPradesh
# 105     564321  ''1113950522000413  AndhraPradesh
# 106     584543   112101A100 391959  AndhraPradesh
# 107     526278  ''1123121254352318  AndhraPradesh
# 108     505934   "1123940000304102  AndhraPradesh
# 109     564540  ''1133442101005648  AndhraPradesh
# 110     563824   "1165150128000511  AndhraPradesh
# 111     564910  ''1213280616000791  AndhraPradesh
# 112     456181   "131101A100032180  AndhraPradesh
# 113     586271  ''131101A104064793  AndhraPradesh
# 114     585147  ''1433066201018037  AndhraPradesh
# 115     586085  ''1433066201018110  AndhraPradesh
# 116     529590  ''1451460204001810  AndhraPradesh
# 117     564577  ''1455440502018627  AndhraPradesh
# 118     591275   "1511066103076535  AndhraPradesh
# 119     520597  ''1533581006018703  AndhraPradesh
# 120     594035   "1552770404000346  AndhraPradesh

# %%
del_fail_AP = del_fail[(del_fail.Circle == "AndhraPradesh")]
del_fail_AP
# Out:
#             Date                       StatementId       AccountNumber  \
# 189   05.10.2021  1ec25256d2b3dad3b6190ef20e225579  '113132D012041605'
# 364   06.10.2021  1ec25ce25b4ad8e389580ecdb0fb3573  '132925E119000701'
# 384   06.10.2021  1ec2608152e1dcbeacfe0ef0a4caa889  '1514191213000564'
# 459   06.10.2021  1ec261f82c17d27483490e046118c94f  '1212090101011605'
# 464   06.10.2021  1ec26212aab0d52ea3360e046118c94f  '133316C700000965'
# ...          ...                               ...                 ...
# 3358  27.10.2021  1ec2847dd667d0b3a0710e40024f9825  '131101A100065866'
# 3359  27.10.2021  1ec285223f74d6ef9cba0eefed7d7093  '1564531105001332'
# 3360  27.10.2021  1ec2856ffe55d2bc93e70e25ab6d34ef  '1541246101036885'
# 3361  27.10.2021  1ec285aea76ed22e878b0e25ab6d34ef  '1414380620001184'
# 3362  27.10.2021  1ec285d0a946d670878b0e25ab6d34ef  '132823E623000585'
#
#      ProviderAlias         Circle  SiteCode Statementdate  \
# 189      EPDCAPIND  AndhraPradesh    593521    2021-10-04
# 364      EPDCAPIND  AndhraPradesh    589034    2021-10-04
# 384      EPDCAPIND  AndhraPradesh    591266    2021-10-05
# 459      EPDCAPIND  AndhraPradesh    587374    2021-10-05
# 464      EPDCAPIND  AndhraPradesh    589046    2021-10-04
# ...            ...            ...       ...           ...
# 3358     EPDCAPIND  AndhraPradesh    589478    2021-10-08
# 3359     EPDCAPIND  AndhraPradesh    583062    2021-10-08
# 3360     EPDCAPIND  AndhraPradesh    586660    2021-10-07
# 3361     EPDCAPIND  AndhraPradesh    591857    2021-10-08
# 3362     EPDCAPIND  AndhraPradesh    592913    2021-10-08
#
#                 DeliveryResult  ResponseCode  \
# 189    NOT_WANTED_API_REJECTED           400
# 364    NOT_WANTED_API_REJECTED           400
# 384    NOT_WANTED_API_REJECTED           400
# 459    NOT_WANTED_API_REJECTED           400
# 464    NOT_WANTED_API_REJECTED           400
# ...                        ...           ...
# 3358   NOT_WANTED_API_REJECTED           400
# 3359   NOT_WANTED_API_REJECTED           400
# 3360  NOT_WANTED_API_DUPLICATE           409
# 3361   NOT_WANTED_API_REJECTED           400
# 3362   NOT_WANTED_API_REJECTED           400
#
#                                            ResponseBody
# 189   {"message":"No EB Master found for SiteId/Cons...
# 364   {"message":"No EB Master found for SiteId/Cons...
# 384   {"message":"No EB Master found for SiteId/Cons...
# 459   {"message":"No EB Master found for SiteId/Cons...
# 464   {"message":"No EB Master found for SiteId/Cons...
# ...                                                 ...
# 3358  {"message":"No EB Master found for SiteId/Cons...
# 3359  {"message":"No EB Master found for SiteId/Cons...
# 3360  {"message":"EB Feed details already exists - S...
# 3361  {"message":"No EB Master found for SiteId/Cons...
# 3362  {"message":"No EB Master found for SiteId/Cons...
#
# [94 rows x 10 columns]

# %%
def dfs_tabs(df_list, sheet_list, file_name):
    writer = pd.ExcelWriter(file_name,engine='xlsxwriter')   
    for dataframe, sheet in zip(df_list, sheet_list):
        dataframe.to_excel(writer, sheet_name=sheet, startrow=0 , startcol=0)   
    writer.save()


dfs = [acc_with_issue_AP,del_fail_AP]
sheets = ['Accounts with issues','Undelivered Accounts']    


dfs_tabs(dfs, sheets, 'AndhraPradesh_Undelivered Accounts_Oct01-29.xlsx')

# %% [markdown]
# ### Kerala

# %%
acc_with_issue_KR = acc_with_issues[(acc_with_issues.CircleName == "Kerala")]
acc_with_issue_KR
# Out:
#     Normalized Account Number Account Number Provider Alias Monitoring Status  \
# 179             1145291013050  1145291013050        KSEBIND          INACTIVE
# 180             1145641026194  1145641026194        KSEBIND          INACTIVE
# 181             1145675024983  1145675024983        KSEBIND          INACTIVE
# 182             1146346007351  1146346007351        KSEBIND         AGED_BILL
# 183             1155025010456  1155025010456        KSEBIND          INACTIVE
# 184             1155187007463  1155187007463        KSEBIND          INACTIVE
# 185             1155468017315  1155468017315        KSEBIND          INACTIVE
# 186             1155593019302  1155593019302        KSEBIND          INACTIVE
# 187             1155652020589  1155652020589        KSEBIND          INACTIVE
# 188             1155655015800  1155655015800        KSEBIND          INACTIVE
# 189             1155737013957  1155737013957        KSEBIND          INACTIVE
# 190             1155840030566  1155840030566        KSEBIND         AGED_BILL
# 191             1156005027658  1156005027658        KSEBIND          INACTIVE
# 192             1156541028863  1156541028863        KSEBIND          INACTIVE
# 193             1156584013284  1156584013284        KSEBIND          INACTIVE
# 194             1156722019090  1156722019090        KSEBIND          INACTIVE
# 195             1156749010452  1156749010452        KSEBIND          INACTIVE
# 196             1156768013441  1156768013441        KSEBIND          INACTIVE
# 197             1156838024403  1156838024403        KSEBIND          INACTIVE
# 198             1157000012928  1157000012928        KSEBIND         AGED_BILL
# 199             1157429009055  1157429009055        KSEBIND          INACTIVE
# 200             1165057011906  1165057011906        KSEBIND          INACTIVE
# 201             1165135019498  1165135019498        KSEBIND          INACTIVE
# 202             1165144022009  1165144022009        KSEBIND          INACTIVE
# 203             1165149018630  1165149018630        KSEBIND          INACTIVE
# 204             1165544017297  1165544017297        KSEBIND         AGED_BILL
# 205             1166548016178  1166548016178        KSEBIND          INACTIVE
# 206             1166837021388  1166837021388        KSEBIND          INACTIVE
# 207             1166844012753  1166844012753        KSEBIND          INACTIVE
# 208             1166888022244  1166888022244        KSEBIND          INACTIVE
# 209             1166984006569  1166984006569        KSEBIND          INACTIVE
#
#                                        Detailed Status  Site Code CNBD 2  \
# 179  Since the invoice is not posted for more than ...     545677    NaN
# 180  Since the invoice is not posted for more than ...     545595    NaN
# 181  Since the invoice is not posted for more than ...     506565    NaN
# 182        'No New Bill posted in website after 45days     545280    NaN
# 183  Since the invoice is not posted for more than ...     545247    NaN
# 184  Since the invoice is not posted for more than ...     506610    NaN
# 185  Since the invoice is not posted for more than ...     545228    NaN
# 186  Since the invoice is not posted for more than ...     545231    NaN
# 187  Since the invoice is not posted for more than ...     506575    NaN
# 188  Since the invoice is not posted for more than ...     545241    NaN
# 189  Since the invoice is not posted for more than ...     545223    NaN
# 190        'No New Bill posted in website after 45days     595155  30566
# 191  Since the invoice is not posted for more than ...     545357    NaN
# 192  Since the invoice is not posted for more than ...     577959  28863
# 193  Since the invoice is not posted for more than ...     545320    NaN
# 194  Since the invoice is not posted for more than ...     545708    NaN
# 195  Since the invoice is not posted for more than ...     545662    NaN
# 196  Since the invoice is not posted for more than ...     545665    NaN
# 197  Since the invoice is not posted for more than ...     545880    NaN
# 198        'No New Bill posted in website after 45days     545348    NaN
# 199  Since the invoice is not posted for more than ...     545711    NaN
# 200  Since the invoice is not posted for more than ...     545402    NaN
# 201  Since the invoice is not posted for more than ...     506874    NaN
# 202  Since the invoice is not posted for more than ...     544978    NaN
# 203  Since the invoice is not posted for more than ...     545209    NaN
# 204        'No New Bill posted in website after 45days     545617    NaN
# 205  Since the invoice is not posted for more than ...     545574    NaN
# 206  Since the invoice is not posted for more than ...     545412    NaN
# 207  Since the invoice is not posted for more than ...     545319    NaN
# 208  Since the invoice is not posted for more than ...     545762    NaN
# 209  Since the invoice is not posted for more than ...     590245  36569
#
#     CircleName
# 179     Kerala
# 180     Kerala
# 181     Kerala
# 182     Kerala
# 183     Kerala
# 184     Kerala
# 185     Kerala
# 186     Kerala
# 187     Kerala
# 188     Kerala
# 189     Kerala
# 190     Kerala
# 191     Kerala
# 192     Kerala
# 193     Kerala
# 194     Kerala
# 195     Kerala
# 196     Kerala
# 197     Kerala
# 198     Kerala
# 199     Kerala
# 200     Kerala
# 201     Kerala
# 202     Kerala
# 203     Kerala
# 204     Kerala
# 205     Kerala
# 206     Kerala
# 207     Kerala
# 208     Kerala
# 209     Kerala

# %%
acc_with_issue_KR.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-d5e649d0d406> in <module>
# ----> 1 acc_with_issue_KR.shape
#
# NameError: name 'acc_with_issue_KR' is not defined

# %%
del_fail_KR = del_fail[(del_fail.Circle == "Kerala")]
del_fail_KR
# Out:
#             Date                       StatementId  AccountNumber  \
# 36    04.10.2021  1ec234252105dbbb91330ebd5311d2bf  1145651022429
# 37    04.10.2021  1ec234605abcda1691330ebd5311d2bf  1165644030535
# 38    04.10.2021  1ec23460b183d007a4630ebd5311d2bf  1146928008481
# 39    04.10.2021  1ec2346340e0d67a91330ebd5311d2bf  1145120038235
# 40    04.10.2021  1ec2346862b4dc8291330ebd5311d2bf  1145421035630
# ...          ...                               ...            ...
# 3311  25.10.2021  1ec33a82f497dc2cbb920ee2ba5b9199  1156766023303
# 3318  25.10.2021  1ec35245f230dcd6b93d0e43c9bcfc6d  1165315024572
# 3335  26.10.2021  1ec3586db7c5d137b0e50e9aca07e96f  1166989036569
# 3382  29.10.2021  1ec377ff2bd5d0779e280e3d149fe8e1  1166103013777
# 3383  29.10.2021  1ec378c1dbced3dcbf970e3d149fe8e1  1167498012068
#
#      ProviderAlias  Circle  SiteCode Statementdate            DeliveryResult  \
# 36         KSEBIND  Kerala    589060    2021-10-01   NOT_WANTED_API_REJECTED
# 37         KSEBIND  Kerala    465878    2021-10-01   NOT_WANTED_API_REJECTED
# 38         KSEBIND  Kerala    526342    2021-10-01   NOT_WANTED_API_REJECTED
# 39         KSEBIND  Kerala    545008    2021-10-01   NOT_WANTED_API_REJECTED
# 40         KSEBIND  Kerala    593323    2021-10-01   NOT_WANTED_API_REJECTED
# ...            ...     ...       ...           ...                       ...
# 3311       KSEBIND  Kerala    595942    2021-10-22   NOT_WANTED_API_REJECTED
# 3318       KSEBIND  Kerala    589126    2021-10-23   NOT_WANTED_API_REJECTED
# 3335       KSEBIND  Kerala    590245    2021-10-12   NOT_WANTED_API_REJECTED
# 3382       KSEBIND  Kerala    589230    2021-10-25   NOT_WANTED_API_REJECTED
# 3383       KSEBIND  Kerala    545485    2021-10-01  NOT_WANTED_API_DUPLICATE
#
#       ResponseCode                                       ResponseBody
# 36             404         {"message":"site with id 589060 not found"
# 37             400  {"message":"No EB Master found for SiteId/Cons...
# 38             400  {"message":"No EB Master found for SiteId/Cons...
# 39             400  {"message":"No EB Master found for SiteId/Cons...
# 40             404         {"message":"site with id 593323 not found"
# ...            ...                                                ...
# 3311           400  {"message":"No EB Master found for SiteId/Cons...
# 3318           404         {"message":"site with id 589126 not found"
# 3335           400  {"message":"No EB Master found for SiteId/Cons...
# 3382           404         {"message":"site with id 589230 not found"
# 3383           409  {"message":"EB Feed details already exists - S...
#
# [81 rows x 10 columns]

# %%
def dfs_tabs(df_list, sheet_list, file_name):
    writer = pd.ExcelWriter(file_name,engine='xlsxwriter')   
    for dataframe, sheet in zip(df_list, sheet_list):
        dataframe.to_excel(writer, sheet_name=sheet, startrow=0 , startcol=0)   
    writer.save()


dfs = [acc_with_issue_KR,del_fail_KR]
sheets = ['Accounts with issues','Undelivered Accounts']    


dfs_tabs(dfs, sheets, 'Kerala_Undelivered Accounts_Oct01-29.xlsx')

# %% [markdown]
# ### Chhatisgarh

# %%
acc_with_issue_CH = acc_with_issues[(acc_with_issues.CircleName == "Chhattisgarh")]
acc_with_issue_CH
# Out:
#     Normalized Account Number Account Number  \
# 79                 1001880714     1001880714
# 80                 1002225131     1002225131
# 81                 1002399221     1002399221
# 82                 1002488921     1002488921
# 83                 1002490860     1002490860
# 84                 1002759251     1002759251
# 85                 1003001320     1003001320
# 86                 1004449054     1004449054
# 87                 1004665232     1004665232
# 88                 1004717224     1004717224
# 89                 1005119860     1005119860
# 90                 1005445661     1005445661
# 91                 1006240142     1006240142
# 92                 1006386827     1006386827
# 93                 1006470973     1006470973
# 94                 1006510741     1006510741
# 95                 1007571572     1007571572
# 96                 1007740959     1007740959
# 97                 1007778613     1007778613
# 98                 1007921426     1007921426
# 99                 1007950165     1007950165
# 100                1007982711     1007982711
# 101                1008022704     1008022704
#
#                               Provider Alias Monitoring Status  \
# 79   ChhattisgarhStatePowerDistributionCOIND         AGED_BILL
# 80   ChhattisgarhStatePowerDistributionCOIND         AGED_BILL
# 81   ChhattisgarhStatePowerDistributionCOIND         AGED_BILL
# 82   ChhattisgarhStatePowerDistributionCOIND          INACTIVE
# 83   ChhattisgarhStatePowerDistributionCOIND         AGED_BILL
# 84   ChhattisgarhStatePowerDistributionCOIND          INACTIVE
# 85   ChhattisgarhStatePowerDistributionCOIND         AGED_BILL
# 86   ChhattisgarhStatePowerDistributionCOIND         AGED_BILL
# 87   ChhattisgarhStatePowerDistributionCOIND          INACTIVE
# 88   ChhattisgarhStatePowerDistributionCOIND         AGED_BILL
# 89   ChhattisgarhStatePowerDistributionCOIND         AGED_BILL
# 90   ChhattisgarhStatePowerDistributionCOIND         AGED_BILL
# 91   ChhattisgarhStatePowerDistributionCOIND         AGED_BILL
# 92   ChhattisgarhStatePowerDistributionCOIND          INACTIVE
# 93   ChhattisgarhStatePowerDistributionCOIND         AGED_BILL
# 94   ChhattisgarhStatePowerDistributionCOIND          INACTIVE
# 95   ChhattisgarhStatePowerDistributionCOIND          INACTIVE
# 96   ChhattisgarhStatePowerDistributionCOIND          INACTIVE
# 97   ChhattisgarhStatePowerDistributionCOIND          INACTIVE
# 98   ChhattisgarhStatePowerDistributionCOIND  TEMPLATE_FAILURE
# 99   ChhattisgarhStatePowerDistributionCOIND          INACTIVE
# 100  ChhattisgarhStatePowerDistributionCOIND          INACTIVE
# 101  ChhattisgarhStatePowerDistributionCOIND         AGED_BILL
#
#                                        Detailed Status  Site Code CNBD 2  \
# 79         'No New Bill posted in website after 45days     463356    NaN
# 80         'No New Bill posted in website after 45days     557577    NaN
# 81         'No New Bill posted in website after 45days     557620    NaN
# 82   Since the invoice is not posted for more than ...     528192    NaN
# 83         'No New Bill posted in website after 45days     450624    NaN
# 84   Since the invoice is not posted for more than ...     464539    NaN
# 85         'No New Bill posted in website after 45days     463484    NaN
# 86         'No New Bill posted in website after 45days     522415    NaN
# 87   Since the invoice is not posted for more than ...     523026    NaN
# 88         'No New Bill posted in website after 45days     522336    NaN
# 89         'No New Bill posted in website after 45days     521972    NaN
# 90         'No New Bill posted in website after 45days     525576    NaN
# 91         'No New Bill posted in website after 45days     465772    NaN
# 92   Since the invoice is not posted for more than ...     528249    NaN
# 93         'No New Bill posted in website after 45days     559371    NaN
# 94   Since the invoice is not posted for more than ...     528243    NaN
# 95   Since the invoice is not posted for more than ...     464551    NaN
# 96   Since the invoice is not posted for more than ...     463904    NaN
# 97   Since the invoice is not posted for more than ...     463747    NaN
# 98        Work in progress for some errors in the bill     587809    NaN
# 99   Since the invoice is not posted for more than ...     587825    NaN
# 100  Since the invoice is not posted for more than ...     587978    NaN
# 101        'No New Bill posted in website after 45days     587819    NaN
#
#        CircleName
# 79   Chhattisgarh
# 80   Chhattisgarh
# 81   Chhattisgarh
# 82   Chhattisgarh
# 83   Chhattisgarh
# 84   Chhattisgarh
# 85   Chhattisgarh
# 86   Chhattisgarh
# 87   Chhattisgarh
# 88   Chhattisgarh
# 89   Chhattisgarh
# 90   Chhattisgarh
# 91   Chhattisgarh
# 92   Chhattisgarh
# 93   Chhattisgarh
# 94   Chhattisgarh
# 95   Chhattisgarh
# 96   Chhattisgarh
# 97   Chhattisgarh
# 98   Chhattisgarh
# 99   Chhattisgarh
# 100  Chhattisgarh
# 101  Chhattisgarh

# %%
del_fail_CH = del_fail[(del_fail.Circle == "Chhattisgarh")]
del_fail_CH
# Out:
#             Date                       StatementId AccountNumber  \
# 366   06.10.2021  1ec25d7fd54edbe180f90eeeb76e7983    1008289215
# 380   06.10.2021  1ec260759a25d4b19df50e85c2d2de21    1002210101
# 391   06.10.2021  1ec26096bad8ddbd9df50e85c2d2de21    1004024282
# 392   06.10.2021  1ec2609c0fbedf289df50e85c2d2de21    1002172113
# 393   06.10.2021  1ec2609c7541d4b49df50e85c2d2de21    1002103979
# ...          ...                               ...           ...
# 2789  15.10.2021  1ec2d14c1358da33bc960ec0b142ced1    1005824018
# 2830  18.10.2021  1ec2d7daba96d5b78aae0e0455d9aa39    1007543674
# 3032  18.10.2021  1ec2d999deafd578b3e00ec5cad7f817    1008228219
# 3050  18.10.2021  1ec2e70598d9daf4a16c0e3eeb8475af    1004250093
# 3191  19.10.2021  1ec300f99543dd5f98ea0ef6524c2469    1005721542
#
#                                 ProviderAlias        Circle  SiteCode  \
# 366   ChhattisgarhStatePowerDistributionCOIND  Chhattisgarh    451105
# 380   ChhattisgarhStatePowerDistributionCOIND  Chhattisgarh    463684
# 391   ChhattisgarhStatePowerDistributionCOIND  Chhattisgarh    463832
# 392   ChhattisgarhStatePowerDistributionCOIND  Chhattisgarh    463421
# 393   ChhattisgarhStatePowerDistributionCOIND  Chhattisgarh    463477
# ...                                       ...           ...       ...
# 2789  ChhattisgarhStatePowerDistributionCOIND  Chhattisgarh    451094
# 2830  ChhattisgarhStatePowerDistributionCOIND  Chhattisgarh    450696
# 3032  ChhattisgarhStatePowerDistributionCOIND  Chhattisgarh    583780
# 3050  ChhattisgarhStatePowerDistributionCOIND  Chhattisgarh    463277
# 3191  ChhattisgarhStatePowerDistributionCOIND  Chhattisgarh    525356
#
#      Statementdate           DeliveryResult  ResponseCode  \
# 366     2021-10-07  NOT_WANTED_API_REJECTED           400
# 380     2021-10-05  NOT_WANTED_API_REJECTED           400
# 391     2021-10-05  NOT_WANTED_API_REJECTED           400
# 392     2021-10-05  NOT_WANTED_API_REJECTED           400
# 393     2021-10-05  NOT_WANTED_API_REJECTED           400
# ...            ...                      ...           ...
# 2789    2021-10-13  NOT_WANTED_API_REJECTED           400
# 2830    2021-10-15  NOT_WANTED_API_REJECTED           400
# 3032    2021-10-15  NOT_WANTED_API_REJECTED           400
# 3050    2021-10-14  NOT_WANTED_API_REJECTED           400
# 3191    2021-10-10  NOT_WANTED_API_REJECTED           400
#
#                                            ResponseBody
# 366   {"message":"No EB Master found for SiteId/Cons...
# 380   {"message":"No EB Master found for SiteId/Cons...
# 391   {"message":"No EB Master found for SiteId/Cons...
# 392   {"message":"No EB Master found for SiteId/Cons...
# 393   {"message":"No EB Master found for SiteId/Cons...
# ...                                                 ...
# 2789  {"message":"No EB Master found for SiteId/Cons...
# 2830  {"message":"No EB Master found for SiteId/Cons...
# 3032  {"message":"No EB Master found for SiteId/Cons...
# 3050  {"message":"No EB Master found for SiteId/Cons...
# 3191       {"message":"No EB Master defined for SiteId"
#
# [93 rows x 10 columns]

# %%
def dfs_tabs(df_list, sheet_list, file_name):
    writer = pd.ExcelWriter(file_name,engine='xlsxwriter')   
    for dataframe, sheet in zip(df_list, sheet_list):
        dataframe.to_excel(writer, sheet_name=sheet, startrow=0 , startcol=0)   
    writer.save()


dfs = [acc_with_issue_CH,del_fail_CH]
sheets = ['Accounts with issues','Undelivered Accounts']    


dfs_tabs(dfs, sheets, 'Chhattisgarh_Undelivered Accounts_Oct01-29.xlsx')

# %% [markdown]
# ### Mumbai

# %%
acc_with_issue_MU = acc_with_issues[(acc_with_issues.CircleName == "Mumbai")]
acc_with_issue_MU
# Out:
#     Normalized Account Number  Account Number  \
# 355              900000053152  9000 0005 3152
# 356              900000899535  9000 0089 9535
# 357                9158308517   915-830-851*7
# 360               13014623145    013014623145
# 361                 400002185    000400002185
#
#                                    Provider Alias Monitoring Status  \
# 355                                  TataPowerIND          INACTIVE
# 356                                  TataPowerIND          INACTIVE
# 357  TheBrihanmumbaiElectricSupplyAndTransportIND          INACTIVE
# 360                        TorrentPowerLimitedIND          INACTIVE
# 361                        TorrentPowerLimitedIND  TEMPLATE_FAILURE
#
#                                        Detailed Status  Site Code     CNBD 2  \
# 355  Since the invoice is not posted for more than ...     567282        NaN
# 356  Since the invoice is not posted for more than ...     508236        NaN
# 357  Since the invoice is not posted for more than ...     522774  915830851
# 360  Since the invoice is not posted for more than ...     592635        NaN
# 361       Work in progress for some errors in the bill     571462        NaN
#
#     CircleName
# 355     Mumbai
# 356     Mumbai
# 357     Mumbai
# 360     Mumbai
# 361     Mumbai

# %%
del_fail_MU = del_fail[(del_fail.Circle == "Mumbai")]
del_fail_MU
# Out:
#             Date                       StatementId   AccountNumber  \
# 54    04.10.2021  1ec233152522dea9bb4d0ebd5311d2bf   528-306-032*7
# 55    04.10.2021  1ec2336f4ef9d227bb4d0ebd5311d2bf   647-800-152*8
# 59    05.10.2021  1ec24a4f95a1d6fcb7900efcd6b8eeed  9000 0089 9546
# 197   05.10.2021  1ec2531ca31ad94abea00ec124a63347   699-534-512*4
# 571   06.10.2021  1ec260f116a3d28c98920efa749562cf   596-520-037*8
# ...          ...                               ...             ...
# 3384  29.10.2021  1ec3792a02e6d2858b380ed95e6094c5        18718260
# 3394  29.10.2021  1ec37dcb05d4dd4a80640e783c7cf2e5       232071508
# 3395  29.10.2021  1ec3807aa747dcfca7a00e0b6aa255cd       334220192
# 3401  29.10.2021  1ec383996413d5f4be890e15626d9e8f   323-289-003*5
# 3402  29.10.2021  1ec383f6a311d823be890e15626d9e8f   799-437-063*2
#
#                                      ProviderAlias  Circle  SiteCode  \
# 54    TheBrihanmumbaiElectricSupplyAndTransportIND  Mumbai    567799
# 55    TheBrihanmumbaiElectricSupplyAndTransportIND  Mumbai    586634
# 59                                    TataPowerIND  Mumbai    531630
# 197   TheBrihanmumbaiElectricSupplyAndTransportIND  Mumbai    463068
# 571   TheBrihanmumbaiElectricSupplyAndTransportIND  Mumbai    464509
# ...                                            ...     ...       ...
# 3384    MaharashtraStateElectricityDistributionIND  Mumbai    591024
# 3394                        TorrentPowerLimitedIND  Mumbai    587292
# 3395    MaharashtraStateElectricityDistributionIND  Mumbai    578447
# 3401  TheBrihanmumbaiElectricSupplyAndTransportIND  Mumbai    592227
# 3402  TheBrihanmumbaiElectricSupplyAndTransportIND  Mumbai    567608
#
#      Statementdate           DeliveryResult  ResponseCode  \
# 54      2021-10-01  NOT_WANTED_API_REJECTED           400
# 55      2021-10-01  NOT_WANTED_API_REJECTED           400
# 59      2021-10-04  NOT_WANTED_API_REJECTED           400
# 197     2021-10-04  NOT_WANTED_API_REJECTED           400
# 571     2021-10-05  NOT_WANTED_API_REJECTED           400
# ...            ...                      ...           ...
# 3384    2021-10-27  NOT_WANTED_API_REJECTED           400
# 3394    2021-10-25  NOT_WANTED_API_REJECTED           400
# 3395    2021-10-28  NOT_WANTED_API_REJECTED           400
# 3401    2021-10-28  NOT_WANTED_API_REJECTED           400
# 3402    2021-10-28  NOT_WANTED_API_REJECTED           400
#
#                                            ResponseBody
# 54    {"message":"No EB Master found for SiteId/Cons...
# 55    {"message":"No EB Master found for SiteId/Cons...
# 59    {"message":"could not execute statement; SQL [...
# 197   {"message":"No EB Master found for SiteId/Cons...
# 571   {"message":"No EB Master found for SiteId/Cons...
# ...                                                 ...
# 3384  {"message":"No EB Master found for SiteId/Cons...
# 3394       {"message":"No EB Master defined for SiteId"
# 3395  {"message":"No EB Master found for SiteId/Cons...
# 3401  {"message":"No EB Master found for SiteId/Cons...
# 3402  {"message":"No EB Master found for SiteId/Cons...
#
# [100 rows x 10 columns]

# %%
def dfs_tabs(df_list, sheet_list, file_name):
    writer = pd.ExcelWriter(file_name,engine='xlsxwriter')   
    for dataframe, sheet in zip(df_list, sheet_list):
        dataframe.to_excel(writer, sheet_name=sheet, startrow=0 , startcol=0)   
    writer.save()


dfs = [acc_with_issue_MU,del_fail_MU]
sheets = ['Accounts with issues','Undelivered Accounts']    


dfs_tabs(dfs, sheets, 'Mumbai_Undelivered Accounts_Oct01-29.xlsx')

# %% [markdown]
# ### Maharashtra

# %%
acc_with_issue_MH = acc_with_issues[(acc_with_issues.CircleName == "Maharashtra")]
acc_with_issue_MH
# Out:
#     Normalized Account Number Account Number  \
# 121               60001311723    60001311723
# 122               60003529157    60003529157
# 123               60006227817    60006227817
# 210              184020198234   184020198234
# 211              210113023656   210113023656
# 212               32513322584   032513322584
# 358               13011186658    13011186658
# 359               13014623099   013014623099
#
#                                  Provider Alias Monitoring Status  \
# 121                       GoaElectricityDeptIND         AGED_BILL
# 122                       GoaElectricityDeptIND     LOGIN_FAILURE
# 123                       GoaElectricityDeptIND          INACTIVE
# 210  MaharashtraStateElectricityDistributionIND  TEMPLATE_FAILURE
# 211  MaharashtraStateElectricityDistributionIND  TEMPLATE_FAILURE
# 212  MaharashtraStateElectricityDistributionIND  TEMPLATE_FAILURE
# 358                      TorrentPowerLimitedIND  TEMPLATE_FAILURE
# 359                      TorrentPowerLimitedIND          INACTIVE
#
#                                        Detailed Status  Site Code CNBD 2  \
# 121        'No New Bill posted in website after 45days     451325    NaN
# 122  Not able to login in website since the credent...     461326    NaN
# 123  Since the invoice is not posted for more than ...     461376    NaN
# 210       Work in progress for some errors in the bill     589214    NaN
# 211       Work in progress for some errors in the bill     596191    NaN
# 212       Work in progress for some errors in the bill     596472    NaN
# 358       Work in progress for some errors in the bill     461493    NaN
# 359  Since the invoice is not posted for more than ...     593873    NaN
#
#       CircleName
# 121  Maharashtra
# 122  Maharashtra
# 123  Maharashtra
# 210  Maharashtra
# 211  Maharashtra
# 212  Maharashtra
# 358  Maharashtra
# 359  Maharashtra

# %%
del_fail_MH = del_fail[(del_fail.Circle == "Maharashtra")]
del_fail_MH
# Out:
#             Date                           StatementId AccountNumber  \
# 0     01.10.2021      1ec21e2e51e3d3b29e9f0e0f977cb1e5   60005671684
# 1     01.10.2021      1ec21e36493ed6f19e9f0e0f977cb1e5   60002942351
# 43    04.10.2021      1ec2349d3113ddc583de0ecb8b7e4a6f   60002561078
# 161   05.10.2021      1ec24fbc11b0dfbcaca00e705fe33a37   13013762648
# 164   05.10.2021      1ec24fbcf9badd5caca00e705fe33a37   13014002191
# ...          ...                                   ...           ...
# 3350  27.10.2021      1ec3642a7219d58d93c90ecb39928415   13013379780
# 3351  27.10.2021      1ec36736b174d9c084260eec6355ce6b    1903431187
# 3371  28.10.2021  1ec37275-818b-d8f5-acf8-0e4e6645e539   60003672536
# 3380  29.10.2021      1ec37275818bd8f5acf80e4e6645e539   60003672536
# 3393  29.10.2021      1ec37dc76b10dc8788ca0e575b71a215   13014480611
#
#                                    ProviderAlias       Circle  SiteCode  \
# 0                          GoaElectricityDeptIND  Maharashtra    461363
# 1                          GoaElectricityDeptIND  Maharashtra    567022
# 43                         GoaElectricityDeptIND  Maharashtra    565894
# 161                       TorrentPowerLimitedIND  Maharashtra    531400
# 164                       TorrentPowerLimitedIND  Maharashtra    531429
# ...                                          ...          ...       ...
# 3350                      TorrentPowerLimitedIND  Maharashtra    567277
# 3351  MaharashtraStateElectricityDistributionIND  Maharashtra    586535
# 3371                       GoaElectricityDeptIND  Maharashtra    461356
# 3380                       GoaElectricityDeptIND  Maharashtra    461356
# 3393                      TorrentPowerLimitedIND  Maharashtra    586979
#
#      Statementdate            DeliveryResult  ResponseCode  \
# 0       2021-10-01   NOT_WANTED_API_REJECTED           400
# 1       2021-10-01  NOT_WANTED_API_DUPLICATE           409
# 43      2021-10-05  NOT_WANTED_API_DUPLICATE           409
# 161     2021-10-01  NOT_WANTED_API_DUPLICATE           409
# 164     2021-10-01  NOT_WANTED_API_DUPLICATE           409
# ...            ...                       ...           ...
# 3350    2021-10-25  NOT_WANTED_API_DUPLICATE           409
# 3351    2021-10-26   NOT_WANTED_API_REJECTED           400
# 3371    2021-10-29  NOT_WANTED_API_DUPLICATE           409
# 3380    2021-10-29  NOT_WANTED_API_DUPLICATE           409
# 3393    2021-10-27   NOT_WANTED_API_REJECTED           400
#
#                                            ResponseBody
# 0     {"message":"No EB Master found for SiteId/Cons...
# 1     {"message":"EB Feed details already exists - S...
# 43    {"message":"EB Feed details already exists - S...
# 161   {"message":"EB Feed details already exists - S...
# 164   {"message":"EB Feed details already exists - S...
# ...                                                 ...
# 3350  {"message":"EB Feed details already exists - S...
# 3351       {"message":"No EB Master defined for SiteId"
# 3371  {"message":"EB Feed details already exists - S...
# 3380  {"message":"EB Feed details already exists - S...
# 3393       {"message":"No EB Master defined for SiteId"
#
# [127 rows x 10 columns]

# %%
def dfs_tabs(df_list, sheet_list, file_name):
    writer = pd.ExcelWriter(file_name,engine='xlsxwriter')   
    for dataframe, sheet in zip(df_list, sheet_list):
        dataframe.to_excel(writer, sheet_name=sheet, startrow=0 , startcol=0)   
    writer.save()


dfs = [acc_with_issue_MH,del_fail_MH]
sheets = ['Accounts with issues','Undelivered Accounts']    


dfs_tabs(dfs, sheets, 'Maharashtra_Undelivered Accounts_Oct01-29.xlsx')

# %% [markdown]
# ### Orissa

# %%
acc_with_issue_OR = acc_with_issues[(acc_with_issues.CircleName == "Orissa")]
acc_with_issue_OR
# Out:
#     Normalized Account Number  Account Number Provider Alias  \
# 362               80000015695     80000015695      TPCODLIND
# 363               80000016040     80000016040      TPCODLIND
# 364               80000017584     80000017584      TPCODLIND
# 365               80000025959     80000025959      TPCODLIND
# 366               80000082489     80000082489      TPCODLIND
# ..                        ...             ...            ...
# 526              813001110327    813001110327      TPWODLIND
# 527              813001110378    813001110378      TPWODLIND
# 528              813001110468    813001110468      TPWODLIND
# 529              416001110318  4160 0111 0318       WESCOIND
# 530              911001060286  9110 0106 0286       WESCOIND
#
#     Monitoring Status                                    Detailed Status  \
# 362         AGED_BILL        'No New Bill posted in website after 45days
# 363         AGED_BILL        'No New Bill posted in website after 45days
# 364         AGED_BILL        'No New Bill posted in website after 45days
# 365          INACTIVE  Since the invoice is not posted for more than ...
# 366         AGED_BILL        'No New Bill posted in website after 45days
# ..                ...                                                ...
# 526          INACTIVE  Since the invoice is not posted for more than ...
# 527          INACTIVE  Since the invoice is not posted for more than ...
# 528          INACTIVE  Since the invoice is not posted for more than ...
# 529          INACTIVE  Since the invoice is not posted for more than ...
# 530          INACTIVE  Since the invoice is not posted for more than ...
#
#      Site Code    CNBD 2 CircleName
# 362     453686  1-BTS-13     Orissa
# 363     556903  2-BTS-31     Orissa
# 364     453691  2-BTS-46     Orissa
# 365     453288  3-BTS-37     Orissa
# 366     453727    1096MI     Orissa
# ..         ...       ...        ...
# 526     568983       NaN     Orissa
# 527     453636       NaN     Orissa
# 528     571767       NaN     Orissa
# 529     508434       NaN     Orissa
# 530     454203       NaN     Orissa
#
# [169 rows x 8 columns]

# %%
del_fail_OR = del_fail[(del_fail.Circle == "Orissa")]
del_fail_OR
# Out:
#             Date                       StatementId AccountNumber  \
# 2274  13.10.2021  1ec2b63965bfdbdd84fb0e7cbc6cb6a5  413001111405
# 2277  13.10.2021  1ec2b6875709dbc397680e7cbc6cb6a5  413001111403
# 2454  14.10.2021  1ec2c3d4ccc0d9d488340e4fd7b4be09  814001111058
# 2455  14.10.2021  1ec2c3fb6fd2ddbb88340e4fd7b4be09  512001110952
# 2470  14.10.2021  1ec2c4b0fcecd12a9a180e1cffb99807  515001110830
# ...          ...                               ...           ...
# 3333  26.10.2021  1ec35866f126d9b69e770e41cfc981a9  523201340124
# 3334  26.10.2021  1ec3586b2c99de1e9e770e41cfc981a9  325402340011
# 3336  26.10.2021  1ec3587392dcd2d485330ebd9ff1854d  311001020710
# 3342  27.10.2021  1ec3606b551bdfa38cb30eff2393ae6d  325401340082
# 3347  27.10.2021  1ec363cb0216d97a9a7f0efb3424da6f  523303340069
#
#      ProviderAlias  Circle  SiteCode Statementdate            DeliveryResult  \
# 2274     TPWODLIND  Orissa    568999    2021-10-11   NOT_WANTED_API_REJECTED
# 2277     TPWODLIND  Orissa    569345    2021-10-11   NOT_WANTED_API_REJECTED
# 2454     TPWODLIND  Orissa    521300    2021-10-16  NOT_WANTED_API_DUPLICATE
# 2455     TPWODLIND  Orissa    524584    2021-10-16  NOT_WANTED_API_DUPLICATE
# 2470     TPWODLIND  Orissa    578244    2021-10-16  NOT_WANTED_API_DUPLICATE
# ...            ...     ...       ...           ...                       ...
# 3333     TPNODLIND  Orissa    454505    2021-10-25   NOT_WANTED_API_REJECTED
# 3334     TPNODLIND  Orissa    557295    2021-10-25   NOT_WANTED_API_REJECTED
# 3336     TPSODLIND  Orissa    556980    2021-10-23   NOT_WANTED_API_REJECTED
# 3342     TPNODLIND  Orissa    557296    2021-10-25   NOT_WANTED_API_REJECTED
# 3347     TPNODLIND  Orissa    454415    2021-10-25   NOT_WANTED_API_REJECTED
#
#       ResponseCode                                       ResponseBody
# 2274           400  {"message":"No EB Master found for SiteId/Cons...
# 2277           400  {"message":"No EB Master found for SiteId/Cons...
# 2454           409  {"message":"EB Feed details already exists - S...
# 2455           409  {"message":"EB Feed details already exists - S...
# 2470           409  {"message":"EB Feed details already exists - S...
# ...            ...                                                ...
# 3333           400       {"message":"No EB Master defined for SiteId"
# 3334           400  {"message":"No EB Master found for SiteId/Cons...
# 3336           400  {"message":"No EB Master found for SiteId/Cons...
# 3342           400  {"message":"No EB Master found for SiteId/Cons...
# 3347           400  {"message":"No EB Master found for SiteId/Cons...
#
# [210 rows x 10 columns]

# %%
def dfs_tabs(df_list, sheet_list, file_name):
    writer = pd.ExcelWriter(file_name,engine='xlsxwriter')   
    for dataframe, sheet in zip(df_list, sheet_list):
        dataframe.to_excel(writer, sheet_name=sheet, startrow=0 , startcol=0)   
    writer.save()


dfs = [acc_with_issue_OR,del_fail_OR]
sheets = ['Accounts with issues','Undelivered Accounts']    


dfs_tabs(dfs, sheets, 'Orissa_Undelivered Accounts_Oct01-29.xlsx')

# %% [markdown]
# ### Tamil Nadu

# %%
acc_with_issue_TN = acc_with_issues[(acc_with_issues.CircleName == "TamilNadu")]
acc_with_issue_TN
# Out:
#     Normalized Account Number Account Number                Provider Alias  \
# 238                1001056197    01001056197  TamilNaduElectricityBoardIND
# 239                1004006768    01004006768  TamilNaduElectricityBoardIND
# 240               10180031003   010180031003  TamilNaduElectricityBoardIND
# 241               10180081384   010180081384  TamilNaduElectricityBoardIND
# 242                1062011441    01062011441  TamilNaduElectricityBoardIND
# ..                        ...            ...                           ...
# 350               94600091875   094600091875  TamilNaduElectricityBoardIND
# 351               94610013906   094610013906  TamilNaduElectricityBoardIND
# 352                9538007677    09538007677  TamilNaduElectricityBoardIND
# 353               95440021955   095440021955  TamilNaduElectricityBoardIND
# 354               95550094561   095550094561  TamilNaduElectricityBoardIND
#
#     Monitoring Status                                    Detailed Status  \
# 238          INACTIVE  Since the invoice is not posted for more than ...
# 239          INACTIVE  Since the invoice is not posted for more than ...
# 240   ACCOUNT_MISSING  Account is missing in website so please check ...
# 241   ACCOUNT_MISSING  Account is missing in website so please check ...
# 242          INACTIVE  Since the invoice is not posted for more than ...
# ..                ...                                                ...
# 350   ACCOUNT_MISSING  Account is missing in website so please check ...
# 351   ACCOUNT_MISSING  Account is missing in website so please check ...
# 352          INACTIVE  Since the invoice is not posted for more than ...
# 353   ACCOUNT_MISSING  Account is missing in website so please check ...
# 354   ACCOUNT_MISSING  Account is missing in website so please check ...
#
#      Site Code CNBD 2 CircleName
# 238     546288    NaN  TamilNadu
# 239     546429    NaN  TamilNadu
# 240     546537    NaN  TamilNadu
# 241     546630    NaN  TamilNadu
# 242     546683    NaN  TamilNadu
# ..         ...    ...        ...
# 350     575419    NaN  TamilNadu
# 351     526875    NaN  TamilNadu
# 352     545980    NaN  TamilNadu
# 353     546400    NaN  TamilNadu
# 354     583530    NaN  TamilNadu
#
# [117 rows x 8 columns]

# %%
del_fail_TN = del_fail[(del_fail.Circle == "TamilNadu")]
del_fail_TN
# Out:
#             Date                           StatementId AccountNumber  \
# 5     04.10.2021      1ec22fbae2aada029b420e1b02cd6113   32040111871
# 47    04.10.2021      1ec23880db6cd996b8b90e6f2d7c0625   32590043381
# 172   05.10.2021      1ec250b7a576db93a3400ea9967be5d7   30480013550
# 179   05.10.2021      1ec2519dfb98d4f1a64b0ef4c3e1a3dd   52040033607
# 180   05.10.2021      1ec251a060c9dd32a64b0ef4c3e1a3dd   52090101062
# 190   05.10.2021      1ec25260f9d6d143b74a0ef4c3e1a3dd   22030122084
# 389   06.10.2021      1ec26092b1ddd8a08f410ea1ece061d7   51580041639
# 422   06.10.2021      1ec261250eebd2e1a1490ec1e3b17b07    7246014419
# 751   07.10.2021      1ec26c939e95dedbbef40efca364bc13   52060043183
# 943   08.10.2021      1ec271ce83b4da17ad1e0e610fdb4d9f   50072202469
# 1127  08.10.2021      1ec27b538bffd206be4f0e225bfc316f   30050042983
# 1133  08.10.2021      1ec27b7b9fb5df068fe90e6276e7ddf1   31390071160
# 1230  11.10.2021      1ec27f13c817d005b3750e55e26048e9   95530071041
# 1302  11.10.2021      1ec2874603d4dc859d260e346a7149e5   70530171207
# 1330  11.10.2021      1ec287a6c21fda5591df0e61c817d6bb    9218023413
# 1341  11.10.2021      1ec287c84bd0daab9fde0e61c817d6bb    3128008911
# 1345  11.10.2021      1ec287cbbec6d41a9fde0e61c817d6bb   31600022242
# 1359  11.10.2021      1ec287f21822de5298a30e61c817d6bb   65410161729
# 1366  11.10.2021      1ec288006d2bd66796c70e346a7149e5   40080062026
# 1381  11.10.2021      1ec2883e1cbdd01596c70e346a7149e5   32510101057
# 1388  11.10.2021      1ec2885308a1d67f96c70e346a7149e5    2248006505
# 1985  12.10.2021      1ec2a8835b6ed49f90210e7d98ba0431    8045009467
# 2023  12.10.2021      1ec2a98067e7d8f086270ed5ea792275   10730011370
# 2028  12.10.2021      1ec2a9c1cd97d254a4cc0ec65239d9df    9328015326
# 2141  13.10.2021      1ec2b05f3825db2e97080ea5bbaa6b7d   92330153916
# 2321  13.10.2021      1ec2b7c0f6eedeb0acd10ed1050231c7   41350062262
# 2322  13.10.2021      1ec2b7c92c0cda62b4bb0efdfa9dad53     921303481
# 2353  13.10.2021      1ec2b9029768d1b58bf40ea06d1a8b41    1072133353
# 2414  14.10.2021      1ec2bdc4aad3dedfabc70e7278cda5eb    7069020851
# 2423  14.10.2021      1ec2c018d9d2dc68abef0e7cbc6cb6a5   80090032794
# 2519  14.10.2021      1ec2c55a3431dee5a6890e0e4711ec6f   63170071010
# 2521  14.10.2021      1ec2c55deebcdb4ba6890e0e4711ec6f   64580121326
# 2568  14.10.2021      1ec2c68f0c9fd1dabd990e1cffb99807    6111022724
# 3051  18.10.2021      1ec2e80d3260dace9b5c0e75fecc64df   51180132279
# 3061  18.10.2021      1ec2f338026bd26781f50e6a34ae1f7f   10190093047
# 3065  18.10.2021      1ec2f38f7c61d2f399a40e5632ccc59d    5261018406
# 3074  18.10.2021      1ec2e87e100ad02a9b5c0e75fecc64df   31630082380
# 3075  18.10.2021      1ec2e8840411d6a19b5c0e75fecc64df   32840017154
# 3076  18.10.2021      1ec2e93caaced02b89640e01ecd812b3   51230092883
# 3083  19.10.2021      1ec2fc84b326d06a9b5e0e5630d7e293    9047112884
# 3210  20.10.2021      1ec30f79b14ad7859ac90e6a042e24a7   44620083055
# 3275  21.10.2021      1ec31bd960f0d7eea2df0e65b0c65add    6111011860
# 3278  21.10.2021      1ec31cb37dc4df8cb4690e692beb693b   70540021446
# 3316  25.10.2021      1ec3417cac2fd8eb8dc40e27f21b1d0f    9249254772
# 3337  26.10.2021      1ec358bc6985d1f584e10ebb936b14e9   71330151515
# 3338  26.10.2021      1ec358cb154fd06dbe5c0ef602ec8b5d   95700121014
# 3339  26.10.2021      1ec3596f0fcdd2fe9b110ef602ec8b5d   63240111083
# 3343  27.10.2021      1ec361324515d0ae9c670e81dd9ee95b   91650051044
# 3344  27.10.2021      1ec361f9cb92dc4e947b0e60dabf1427    7388016748
# 3352  27.10.2021      1ec367520d18dc0f85b00e92a94195f3   60100053447
# 3363  28.10.2021  1ec36de2-c6ec-d8ca-8797-0e4e6645e539    7279009977
# 3372  29.10.2021      1ec36de2c6ecd8ca87970e4e6645e539    7279009977
# 3398  29.10.2021      1ec3825fe65ed9d197a20e15626d9e8f    5172016695
# 3400  29.10.2021      1ec382e3e91ddb31807d0e0b6aa255cd   72380057280
#
#                      ProviderAlias     Circle  SiteCode Statementdate  \
# 5     TamilNaduElectricityBoardIND  TamilNadu    588993    2021-10-01
# 47    TamilNaduElectricityBoardIND  TamilNadu    590540    2021-10-02
# 172   TamilNaduElectricityBoardIND  TamilNadu    588984    2021-10-04
# 179   TamilNaduElectricityBoardIND  TamilNadu    589242    2021-10-01
# 180   TamilNaduElectricityBoardIND  TamilNadu    589860    2021-10-04
# 190   TamilNaduElectricityBoardIND  TamilNadu    576324    2021-10-04
# 389   TamilNaduElectricityBoardIND  TamilNadu    589030    2021-10-05
# 422   TamilNaduElectricityBoardIND  TamilNadu    583517    2021-10-05
# 751   TamilNaduElectricityBoardIND  TamilNadu    586694    2021-10-05
# 943   TamilNaduElectricityBoardIND  TamilNadu    576697    2021-10-06
# 1127  TamilNaduElectricityBoardIND  TamilNadu    547076    2021-10-06
# 1133  TamilNaduElectricityBoardIND  TamilNadu    589799    2021-10-07
# 1230  TamilNaduElectricityBoardIND  TamilNadu    589824    2021-10-07
# 1302  TamilNaduElectricityBoardIND  TamilNadu    547314    2021-10-07
# 1330  TamilNaduElectricityBoardIND  TamilNadu    548807    2021-10-08
# 1341  TamilNaduElectricityBoardIND  TamilNadu    588256    2021-10-08
# 1345  TamilNaduElectricityBoardIND  TamilNadu    589249    2021-10-08
# 1359  TamilNaduElectricityBoardIND  TamilNadu    545974    2021-10-08
# 1366  TamilNaduElectricityBoardIND  TamilNadu    590683    2021-10-08
# 1381  TamilNaduElectricityBoardIND  TamilNadu    547046    2021-10-08
# 1388  TamilNaduElectricityBoardIND  TamilNadu    589884    2021-10-08
# 1985  TamilNaduElectricityBoardIND  TamilNadu    548445    2021-10-10
# 2023  TamilNaduElectricityBoardIND  TamilNadu    581815    2021-10-11
# 2028  TamilNaduElectricityBoardIND  TamilNadu    547016    2021-10-11
# 2141  TamilNaduElectricityBoardIND  TamilNadu    588592    2021-10-11
# 2321  TamilNaduElectricityBoardIND  TamilNadu    590708    2021-10-12
# 2322  TamilNaduElectricityBoardIND  TamilNadu    546828    2021-10-12
# 2353  TamilNaduElectricityBoardIND  TamilNadu    586354    2021-10-05
# 2414  TamilNaduElectricityBoardIND  TamilNadu    590547    2021-10-09
# 2423  TamilNaduElectricityBoardIND  TamilNadu    583740    2021-10-12
# 2519  TamilNaduElectricityBoardIND  TamilNadu    589828    2021-10-13
# 2521  TamilNaduElectricityBoardIND  TamilNadu    589886    2021-10-11
# 2568  TamilNaduElectricityBoardIND  TamilNadu    586067    2021-10-12
# 3051  TamilNaduElectricityBoardIND  TamilNadu    547217    2021-10-16
# 3061  TamilNaduElectricityBoardIND  TamilNadu    585231    2021-10-16
# 3065  TamilNaduElectricityBoardIND  TamilNadu    577628    2021-10-09
# 3074  TamilNaduElectricityBoardIND  TamilNadu    589759    2021-10-16
# 3075  TamilNaduElectricityBoardIND  TamilNadu    589897    2021-10-16
# 3076  TamilNaduElectricityBoardIND  TamilNadu    547197    2021-10-16
# 3083  TamilNaduElectricityBoardIND  TamilNadu    585323    2021-10-18
# 3210  TamilNaduElectricityBoardIND  TamilNadu    590711    2021-10-19
# 3275  TamilNaduElectricityBoardIND  TamilNadu    586212    2021-10-19
# 3278  TamilNaduElectricityBoardIND  TamilNadu    591058    2021-10-12
# 3316  TamilNaduElectricityBoardIND  TamilNadu    588845    2021-10-22
# 3337  TamilNaduElectricityBoardIND  TamilNadu    589248    2021-10-22
# 3338  TamilNaduElectricityBoardIND  TamilNadu    590132    2021-10-22
# 3339  TamilNaduElectricityBoardIND  TamilNadu    589251    2021-10-24
# 3343  TamilNaduElectricityBoardIND  TamilNadu    589263    2021-10-23
# 3344  TamilNaduElectricityBoardIND  TamilNadu    589825    2021-10-26
# 3352  TamilNaduElectricityBoardIND  TamilNadu    585897    2021-10-26
# 3363  TamilNaduElectricityBoardIND  TamilNadu    586637    2021-10-25
# 3372  TamilNaduElectricityBoardIND  TamilNadu    586637    2021-10-25
# 3398  TamilNaduElectricityBoardIND  TamilNadu    590567    2021-10-28
# 3400  TamilNaduElectricityBoardIND  TamilNadu    587295    2021-10-28
#
#                DeliveryResult  ResponseCode  \
# 5     NOT_WANTED_API_REJECTED           400
# 47    NOT_WANTED_API_REJECTED           400
# 172   NOT_WANTED_API_REJECTED           400
# 179   NOT_WANTED_API_REJECTED           400
# 180   NOT_WANTED_API_REJECTED           400
# 190   NOT_WANTED_API_REJECTED           400
# 389   NOT_WANTED_API_REJECTED           400
# 422   NOT_WANTED_API_REJECTED           400
# 751   NOT_WANTED_API_REJECTED           400
# 943   NOT_WANTED_API_REJECTED           400
# 1127  NOT_WANTED_API_REJECTED           400
# 1133  NOT_WANTED_API_REJECTED           400
# 1230  NOT_WANTED_API_REJECTED           400
# 1302  NOT_WANTED_API_REJECTED           400
# 1330  NOT_WANTED_API_REJECTED           400
# 1341  NOT_WANTED_API_REJECTED           400
# 1345  NOT_WANTED_API_REJECTED           400
# 1359  NOT_WANTED_API_REJECTED           400
# 1366  NOT_WANTED_API_REJECTED           400
# 1381  NOT_WANTED_API_REJECTED           400
# 1388  NOT_WANTED_API_REJECTED           400
# 1985  NOT_WANTED_API_REJECTED           400
# 2023  NOT_WANTED_API_REJECTED           400
# 2028  NOT_WANTED_API_REJECTED           400
# 2141  NOT_WANTED_API_REJECTED           400
# 2321  NOT_WANTED_API_REJECTED           400
# 2322  NOT_WANTED_API_REJECTED           400
# 2353  NOT_WANTED_API_REJECTED           400
# 2414  NOT_WANTED_API_REJECTED           400
# 2423  NOT_WANTED_API_REJECTED           400
# 2519  NOT_WANTED_API_REJECTED           400
# 2521  NOT_WANTED_API_REJECTED           400
# 2568  NOT_WANTED_API_REJECTED           400
# 3051  NOT_WANTED_API_REJECTED           400
# 3061  NOT_WANTED_API_REJECTED           400
# 3065  NOT_WANTED_API_REJECTED           400
# 3074  NOT_WANTED_API_REJECTED           400
# 3075  NOT_WANTED_API_REJECTED           400
# 3076  NOT_WANTED_API_REJECTED           400
# 3083  NOT_WANTED_API_REJECTED           400
# 3210  NOT_WANTED_API_REJECTED           400
# 3275  NOT_WANTED_API_REJECTED           400
# 3278  NOT_WANTED_API_REJECTED           400
# 3316  NOT_WANTED_API_REJECTED           400
# 3337  NOT_WANTED_API_REJECTED           400
# 3338  NOT_WANTED_API_REJECTED           400
# 3339  NOT_WANTED_API_REJECTED           400
# 3343  NOT_WANTED_API_REJECTED           400
# 3344  NOT_WANTED_API_REJECTED           400
# 3352  NOT_WANTED_API_REJECTED           400
# 3363  NOT_WANTED_API_REJECTED           400
# 3372  NOT_WANTED_API_REJECTED           400
# 3398  NOT_WANTED_API_REJECTED           400
# 3400  NOT_WANTED_API_REJECTED           400
#
#                                            ResponseBody
# 5          {"message":"No EB Master defined for SiteId"
# 47         {"message":"No EB Master defined for SiteId"
# 172        {"message":"No EB Master defined for SiteId"
# 179        {"message":"No EB Master defined for SiteId"
# 180        {"message":"No EB Master defined for SiteId"
# 190   {"message":"No EB Master found for SiteId/Cons...
# 389        {"message":"No EB Master defined for SiteId"
# 422   {"message":"No EB Master found for SiteId/Cons...
# 751        {"message":"No EB Master defined for SiteId"
# 943   {"message":"No EB Master found for SiteId/Cons...
# 1127  {"message":"No EB Master found for SiteId/Cons...
# 1133       {"message":"No EB Master defined for SiteId"
# 1230       {"message":"No EB Master defined for SiteId"
# 1302  {"message":"No EB Master found for SiteId/Cons...
# 1330  {"message":"No EB Master found for SiteId/Cons...
# 1341       {"message":"No EB Master defined for SiteId"
# 1345       {"message":"No EB Master defined for SiteId"
# 1359  {"message":"No EB Master found for SiteId/Cons...
# 1366       {"message":"No EB Master defined for SiteId"
# 1381  {"message":"No EB Master found for SiteId/Cons...
# 1388       {"message":"No EB Master defined for SiteId"
# 1985  {"message":"No EB Master found for SiteId/Cons...
# 2023  {"message":"No EB Master found for SiteId/Cons...
# 2028  {"message":"No EB Master found for SiteId/Cons...
# 2141       {"message":"No EB Master defined for SiteId"
# 2321       {"message":"No EB Master defined for SiteId"
# 2322  {"message":"No EB Master found for SiteId/Cons...
# 2353       {"message":"No EB Master defined for SiteId"
# 2414       {"message":"No EB Master defined for SiteId"
# 2423  {"message":"No EB Master found for SiteId/Cons...
# 2519       {"message":"No EB Master defined for SiteId"
# 2521       {"message":"No EB Master defined for SiteId"
# 2568       {"message":"No EB Master defined for SiteId"
# 3051  {"message":"No EB Master found for SiteId/Cons...
# 3061  {"message":"No EB Master found for SiteId/Cons...
# 3065  {"message":"No EB Master found for SiteId/Cons...
# 3074       {"message":"No EB Master defined for SiteId"
# 3075       {"message":"No EB Master defined for SiteId"
# 3076  {"message":"No EB Master found for SiteId/Cons...
# 3083  {"message":"No EB Master found for SiteId/Cons...
# 3210       {"message":"No EB Master defined for SiteId"
# 3275       {"message":"No EB Master defined for SiteId"
# 3278       {"message":"No EB Master defined for SiteId"
# 3316       {"message":"No EB Master defined for SiteId"
# 3337       {"message":"No EB Master defined for SiteId"
# 3338       {"message":"No EB Master defined for SiteId"
# 3339       {"message":"No EB Master defined for SiteId"
# 3343       {"message":"No EB Master defined for SiteId"
# 3344       {"message":"No EB Master defined for SiteId"
# 3352       {"message":"No EB Master defined for SiteId"
# 3363       {"message":"No EB Master defined for SiteId"
# 3372       {"message":"No EB Master defined for SiteId"
# 3398  {"message":"No EB Master found for SiteId/Cons...
# 3400       {"message":"No EB Master defined for SiteId"

# %%
def dfs_tabs(df_list, sheet_list, file_name):
    writer = pd.ExcelWriter(file_name,engine='xlsxwriter')   
    for dataframe, sheet in zip(df_list, sheet_list):
        dataframe.to_excel(writer, sheet_name=sheet, startrow=0 , startcol=0)   
    writer.save()


dfs = [acc_with_issue_TN,del_fail_TN]
sheets = ['Accounts with issues','Undelivered Accounts']    


dfs_tabs(dfs, sheets, 'TamilNadu_Undelivered Accounts_Oct01-29.xlsx')

# %% [markdown]
# ### Madhya Pradesh

# %%
acc_with_issue_MP = acc_with_issues[(acc_with_issues.CircleName == "MadhyaPradesh")]
acc_with_issue_MP
# Out:
#     Normalized Account Number Account Number  \
# 213               N2244024335    N2244024335
# 214               N2395006729    N2395006729
# 215               N2433000996    N2433000996
# 216               N2433001865    N2433001865
# 217               N2433002870    N2433002870
# 218               N2433006661    N2433006661
# 219               N2433008741    N2433008741
# 220               N2433010964    N2433010964
# 221               N2433011608    N2433011608
# 222               N2433014170    N2433014170
# 223               N2433015442    N2433015442
# 224               N2433018045    N2433018045
# 225               N3282023161    N3282023161
# 226               N3404008302    N3404008302
# 227               N3478012102    N3478012102
# 228               N3672013188    N3672013188
# 229               N3672013624    N3672013624
# 230               N3672020944    N3672020944
# 231               N3672022303    N3672022303
# 232               N3818007628    N3818007628
# 233             1345010434504  1345010434504
# 234              584308899306   584308899306
# 235              584413175250   584413175250
# 236               N1141021062    N1141021062
# 237               N1834002495    N1834002495
#
#                          Provider Alias Monitoring Status  \
# 213   MPMadhyaKshetraVidyutVitaranCoIND          INACTIVE
# 214   MPMadhyaKshetraVidyutVitaranCoIND  TEMPLATE_FAILURE
# 215   MPMadhyaKshetraVidyutVitaranCoIND  TEMPLATE_FAILURE
# 216   MPMadhyaKshetraVidyutVitaranCoIND  TEMPLATE_FAILURE
# 217   MPMadhyaKshetraVidyutVitaranCoIND  TEMPLATE_FAILURE
# 218   MPMadhyaKshetraVidyutVitaranCoIND  TEMPLATE_FAILURE
# 219   MPMadhyaKshetraVidyutVitaranCoIND  TEMPLATE_FAILURE
# 220   MPMadhyaKshetraVidyutVitaranCoIND  TEMPLATE_FAILURE
# 221   MPMadhyaKshetraVidyutVitaranCoIND  TEMPLATE_FAILURE
# 222   MPMadhyaKshetraVidyutVitaranCoIND  TEMPLATE_FAILURE
# 223   MPMadhyaKshetraVidyutVitaranCoIND  TEMPLATE_FAILURE
# 224   MPMadhyaKshetraVidyutVitaranCoIND  TEMPLATE_FAILURE
# 225  MPPaschimKshetraVidyutVitaranCoIND         AGED_BILL
# 226  MPPaschimKshetraVidyutVitaranCoIND  TEMPLATE_FAILURE
# 227  MPPaschimKshetraVidyutVitaranCoIND         AGED_BILL
# 228  MPPaschimKshetraVidyutVitaranCoIND  TEMPLATE_FAILURE
# 229  MPPaschimKshetraVidyutVitaranCoIND  TEMPLATE_FAILURE
# 230  MPPaschimKshetraVidyutVitaranCoIND  TEMPLATE_FAILURE
# 231  MPPaschimKshetraVidyutVitaranCoIND  TEMPLATE_FAILURE
# 232  MPPaschimKshetraVidyutVitaranCoIND  TEMPLATE_FAILURE
# 233      MPPoorvKshetraVidyutVitaranIND          INACTIVE
# 234      MPPoorvKshetraVidyutVitaranIND          INACTIVE
# 235      MPPoorvKshetraVidyutVitaranIND          INACTIVE
# 236      MPPoorvKshetraVidyutVitaranIND         AGED_BILL
# 237      MPPoorvKshetraVidyutVitaranIND         AGED_BILL
#
#                                        Detailed Status  Site Code  \
# 213  Since the invoice is not posted for more than ...     585565
# 214       Work in progress for some errors in the bill     449848
# 215       Work in progress for some errors in the bill     461698
# 216       Work in progress for some errors in the bill     461703
# 217       Work in progress for some errors in the bill     461701
# 218       Work in progress for some errors in the bill     461702
# 219       Work in progress for some errors in the bill     557537
# 220       Work in progress for some errors in the bill     461694
# 221       Work in progress for some errors in the bill     461695
# 222       Work in progress for some errors in the bill     461696
# 223       Work in progress for some errors in the bill     558144
# 224       Work in progress for some errors in the bill     557848
# 225        'No New Bill posted in website after 45days     584984
# 226       Work in progress for some errors in the bill     461617
# 227        'No New Bill posted in website after 45days     583824
# 228       Work in progress for some errors in the bill     461864
# 229       Work in progress for some errors in the bill     464519
# 230       Work in progress for some errors in the bill     588831
# 231       Work in progress for some errors in the bill     595180
# 232       Work in progress for some errors in the bill     450154
# 233  Since the invoice is not posted for more than ...     461810
# 234  Since the invoice is not posted for more than ...     461723
# 235  Since the invoice is not posted for more than ...     461709
# 236        'No New Bill posted in website after 45days     558049
# 237        'No New Bill posted in website after 45days     586135
#
#                            CNBD 2     CircleName
# 213  2304204-VBN80-36-N2244024335  MadhyaPradesh
# 214   2574527-NGR90-5-N2395006729  MadhyaPradesh
# 215  2454433-HRD97-90-N2433000996  MadhyaPradesh
# 216  2454433-HRD96-90-N2433001865  MadhyaPradesh
# 217  2454433-HRD97-90-N2433002870  MadhyaPradesh
# 218  2454433-HRD91-90-N2433006661  MadhyaPradesh
# 219  2454433-HRD91-90-N2433008741  MadhyaPradesh
# 220  2454433-HRD96-90-N2433010964  MadhyaPradesh
# 221  2454433-HRD91-90-N2433011608  MadhyaPradesh
# 222           HRD95-90-2433014170  MadhyaPradesh
# 223  2454433-HRD93-90-N2433015442  MadhyaPradesh
# 224  2454433-HRD93-90-N2433018045  MadhyaPradesh
# 225        DCZ22 - 2 - 3282023161  MadhyaPradesh
# 226   3474404-PPM1-17-N3404008302  MadhyaPradesh
# 227       ARZ70 - 43 - 3478012102  MadhyaPradesh
# 228   3634602-BKN24-9-N3672013188  MadhyaPradesh
# 229   3634602-BKN25-8-N3672013624  MadhyaPradesh
# 230         BKN5 - 1 - 3672020944  MadhyaPradesh
# 231         BKN6 - 9 - 3672022303  MadhyaPradesh
# 232    3644808-MHT1-3-N3818007628  MadhyaPradesh
# 233          1345010-74-52-434504  MadhyaPradesh
# 234            584308-90-3-899306  MadhyaPradesh
# 235            584413-90-5-175250  MadhyaPradesh
# 236          BWR90-50-N1141021062  MadhyaPradesh
# 237           JBL3-77-N1834002495  MadhyaPradesh

# %%
del_fail_MP = del_fail[(del_fail.Circle == "MadhyaPradesh")]
del_fail_MP
# Out:
#             Date                       StatementId AccountNumber  \
# 6     04.10.2021  1ec22fbef8c2df70b2140e9b3c24b2e3   N3684002082
# 7     04.10.2021  1ec22fc93228da77b2140e9b3c24b2e3   N3961008424
# 8     04.10.2021  1ec22fcac04cd760b2140e9b3c24b2e3   N3961009268
# 9     04.10.2021  1ec22fce1c6adec1b2140e9b3c24b2e3   N3431011324
# 10    04.10.2021  1ec22fff4051d09dbe840ebd5311d2bf   N3812003619
# ...          ...                               ...           ...
# 3390  29.10.2021  1ec37cd4eb30d0ac81a20e575b71a215   N2558002466
# 3391  29.10.2021  1ec37cd4ec04d78c81a20e575b71a215   N2317040579
# 3396  29.10.2021  1ec380f586fcdef9b4430e41308b7001   N3688009431
# 3397  29.10.2021  1ec382522bedd66f87d10edda61bcaa7   N3688001386
# 3399  29.10.2021  1ec382a56b5fd5bb87d10edda61bcaa7   N3688011387
#
#                            ProviderAlias         Circle  SiteCode  \
# 6     MPPaschimKshetraVidyutVitaranCoIND  MadhyaPradesh    570068
# 7     MPPaschimKshetraVidyutVitaranCoIND  MadhyaPradesh    583811
# 8     MPPaschimKshetraVidyutVitaranCoIND  MadhyaPradesh    557426
# 9     MPPaschimKshetraVidyutVitaranCoIND  MadhyaPradesh    507353
# 10    MPPaschimKshetraVidyutVitaranCoIND  MadhyaPradesh    461656
# ...                                  ...            ...       ...
# 3390   MPMadhyaKshetraVidyutVitaranCoIND  MadhyaPradesh    449972
# 3391   MPMadhyaKshetraVidyutVitaranCoIND  MadhyaPradesh    586550
# 3396  MPPaschimKshetraVidyutVitaranCoIND  MadhyaPradesh    522311
# 3397  MPPaschimKshetraVidyutVitaranCoIND  MadhyaPradesh    461905
# 3399  MPPaschimKshetraVidyutVitaranCoIND  MadhyaPradesh    558127
#
#      Statementdate            DeliveryResult  ResponseCode  \
# 6       2021-10-01   NOT_WANTED_API_REJECTED           400
# 7       2021-10-01   NOT_WANTED_API_REJECTED           400
# 8       2021-10-01   NOT_WANTED_API_REJECTED           400
# 9       2021-10-01   NOT_WANTED_API_REJECTED           400
# 10      2021-10-01   NOT_WANTED_API_REJECTED           400
# ...            ...                       ...           ...
# 3390    2021-10-26  NOT_WANTED_API_DUPLICATE           409
# 3391    2021-10-26  NOT_WANTED_API_DUPLICATE           409
# 3396    2021-10-28   NOT_WANTED_API_REJECTED           400
# 3397    2021-10-28   NOT_WANTED_API_REJECTED           400
# 3399    2021-10-28   NOT_WANTED_API_REJECTED           400
#
#                                            ResponseBody
# 6     {"message":"No EB Master found for SiteId/Cons...
# 7     {"message":"No EB Master found for SiteId/Cons...
# 8     {"message":"No EB Master found for SiteId/Cons...
# 9     {"message":"No EB Master found for SiteId/Cons...
# 10    {"message":"No EB Master found for SiteId/Cons...
# ...                                                 ...
# 3390  {"message":"EB Feed details already exists - S...
# 3391  {"message":"EB Feed details already exists - S...
# 3396  {"message":"No EB Master found for SiteId/Cons...
# 3397  {"message":"No EB Master found for SiteId/Cons...
# 3399  {"message":"No EB Master found for SiteId/Cons...
#
# [2588 rows x 10 columns]

# %%
def dfs_tabs(df_list, sheet_list, file_name):
    writer = pd.ExcelWriter(file_name,engine='xlsxwriter')   
    for dataframe, sheet in zip(df_list, sheet_list):
        dataframe.to_excel(writer, sheet_name=sheet, startrow=0 , startcol=0)   
    writer.save()


dfs = [acc_with_issue_MP,del_fail_MP]
sheets = ['Accounts with issues','Undelivered Accounts']    


dfs_tabs(dfs, sheets, 'MadhyaPradesh_Undelivered Accounts_Oct01-29.xlsx')
